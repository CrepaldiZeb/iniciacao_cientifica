# %%
import pickle
with open('/kaggle/input/pre-processamentob/x_orig_mod_medianfilter.pkl', 'rb') as f:
    X = pickle.load(f)
    
with open('/kaggle/input/pre-processamentob/y_orig_mod.pkl', 'rb') as f:
    Y = pickle.load(f)

# %%
import numpy as np
#Y = Y.astype(np.float32)

# %%
'''import cv2
import numpy as np
from tensorflow.image import resize

# Supondo que X seja uma lista de imagens coloridas.
X_resized = np.array([resize(image, [100, 100]) for image in X])
#imagens_cinza = np.array([cv2.cvtColor(image.astype('uint8'), cv2.COLOR_BGR2GRAY) for image in X_resized])

def converter_para_rgb(imagens_cinza):
    imagens_rgb = np.stack((imagens_cinza,) * 3, axis=-1)
    return imagens_rgb

imagens_rgba = converter_para_rgb(imagens_cinza)



imagens_rgba[0].shape
#X = preprocess_input(imagens_rgba)

X = X_resized
X.shape


# Convertendo a lista em um array NumPy
X = np.array(X)
# Out:
#   Cell In[4], line 1
#     '''import cv2
#     ^
# SyntaxError: incomplete input

# %%
print(np.min(X))
print(np.max(X))
X.shape
# Out:
# 0
# 255
# (9947, 100, 100, 3)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
for i in range(3):
    ax = plt.subplot(1, 3, i+1)
    img = ((X[i]/255) + 1) / 2
    plt.imshow(img)
    plt.axis('off')
plt.show()

# %%
from tensorflow.keras.applications.inception_v3 import preprocess_input  
X = preprocess_input(X)
# Out:
# 2024-07-31 16:57:00.867988: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-31 16:57:00.868087: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-31 16:57:00.980168: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
print(np.min(X))
print(np.max(X))
X.shape
# Out:
# -1.0
# 1.0
# (9947, 100, 100, 3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
import numpy as np

unique, counts = np.unique(Y_train, return_counts=True)
ocorrencias = dict(zip(unique, counts))
print("Distribuição no conjunto de treino")
print(ocorrencias)

unique, counts = np.unique(Y_test, return_counts=True)
ocorrencias = dict(zip(unique, counts))

print("Distribuição no conjunto de teste")
print(ocorrencias)
# Out:
# Distribuição no conjunto de treino
# {0: 6304, 1: 1653}
# Distribuição no conjunto de teste
# {0: 1562, 1: 428}

# %%
'''import os
import cv2
import albumentations as A
from skimage.io import imread, imsave
from pathlib import Path

# transformações
import albumentations as A

transformacoes = A.Compose([
    A.ShiftScaleRotate(shift_limit=0.2, scale_limit=0.2, rotate_limit=40, p=1),
    A.HorizontalFlip(p=0.5),
])



novas = 10

index = 0
labels = []
x_train = []

for arquivo in X_train:
    imagem = arquivo
    holder = Y_train[index]
    index += 1
    for i in range(novas):
        imagem_transformada = transformacoes(image=imagem)['image']
        labels.append(holder)
        x_train.append(imagem_transformada)
        
import numpy as np


X_train = np.array(x_train)  
Y_train = np.array(labels)  
'''
import numpy as np
import albumentations as A

# Transformações
transformacoes = A.Compose([
    A.Rotate(limit=20),
    A.ShiftScaleRotate(shift_limit=0.2, scale_limit=0.2, rotate_limit=0),
    A.HorizontalFlip(),
    A.RandomScale(scale_limit=0.1),
    A.Resize(width=100, height=100, p=1),  # Garante que todas as imagens tenham o mesmo tamanho
])

novas = 4
labels = []
x_train = []

for index, imagem in enumerate(X_train):
    holder = Y_train[index]
    
    # Redimensionar a imagem original para garantir uniformidade
    imagem_resized = transformacoes(image=imagem)['image']
    
    if Y_train[index] == 0:
        labels.append(holder)
        x_train.append(imagem_resized)
    else:
        for i in range(novas):
            imagem_transformada = transformacoes(image=imagem)['image']
            labels.append(holder)
            x_train.append(imagem_transformada)

# Convertendo as listas para arrays NumPy
X_train = np.stack(x_train)  # Usa np.stack para garantir que as imagens sejam empilhadas corretamente
Y_train = np.array(labels)  # Convertendo para NumPy array

# %%
import numpy as np

unique, counts = np.unique(Y_train, return_counts=True)
ocorrencias = dict(zip(unique, counts))
print("Distribuição no conjunto de treino")
print(ocorrencias)

unique, counts = np.unique(Y_test, return_counts=True)
ocorrencias = dict(zip(unique, counts))

print("Distribuição no conjunto de teste")
print(ocorrencias)
# Out:
# Distribuição no conjunto de treino
# {0: 6304, 1: 6612}
# Distribuição no conjunto de teste
# {0: 1562, 1: 428}

# %%
# Criando o objeto StratifiedKFold para 3 folds
from sklearn.model_selection import StratifiedKFold
kfold = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Dicionário para armazenar os dados de treino de cada fold
folds = {}

# Dividindo os dados em folds
for i, (train_index, _) in enumerate(kfold.split(X_train, Y_train)):
    folds[f'x_train_{i+1}'] = X_train[train_index]
    folds[f'y_train_{i+1}'] = Y_train[train_index]

# Agora você tem x_train_1, y_train_1, x_train_2, y_train_2, x_train_3, y_train_3 armazenados no dicionário `folds`
x_train_1, y_train_1 = folds['x_train_1'], folds['y_train_1']
x_train_2, y_train_2 = folds['x_train_2'], folds['y_train_2']
x_train_3, y_train_3 = folds['x_train_3'], folds['y_train_3']

# %%
import numpy as np

unique, counts = np.unique(y_train_1, return_counts=True)
ocorrencias = dict(zip(unique, counts))
print("Distribuição no FOLD 1")
print(ocorrencias)

unique, counts = np.unique(y_train_2, return_counts=True)
ocorrencias = dict(zip(unique, counts))

print("Distribuição no FOLD 2")
print(ocorrencias)

unique, counts = np.unique(y_train_3, return_counts=True)
ocorrencias = dict(zip(unique, counts))

print("Distribuição no FOLD 3")
print(ocorrencias)
# Out:
# Distribuição no FOLD 1
# {0: 4202, 1: 4408}
# Distribuição no FOLD 2
# {0: 4203, 1: 4408}
# Distribuição no FOLD 3
# {0: 4203, 1: 4408}

# %%
print(np.min(X_train))
print(np.max(X_train))
X_train.shape
# Out:
# -1.0
# 1.0
# (12916, 100, 100, 3)

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.applications import InceptionV3

def create_InceptionV3():
    base_model = InceptionV3(input_shape=(100, 100, 3), include_top=False, weights='imagenet')
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    x = Dense(128, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    predictions = Dense(1, activation='sigmoid')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    for layer in base_model.layers:
        layer.trainable = False
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report, roc_auc_score
import numpy as np
import time
import tensorflow as tf
from tensorflow.keras.regularizers import l2

scores = []
tempo = []
historys = []
metricas_por_fold = []
melhor_model = None
melhor_f1_score = 0

if(True):
    start_time = time.time()
    tf.keras.backend.clear_session()
    
    n_splits = 3
    hist = []
    holder = []
    metricas_fold = []
    
    kfold = StratifiedKFold(n_splits=n_splits, shuffle=True)
    
    i = 0
    for train_idx, val_idx in kfold.split(X_train, Y_train):
        tf.keras.backend.clear_session()
        early_stopping = EarlyStopping(monitor='val_acc', patience=10, verbose=1, mode='min', restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2, patience=5, verbose=1, mode='min', min_lr=1e-5)
        modelo = create_InceptionV3()
        X_train_fold, Y_train_fold = X_train[train_idx], Y_train[train_idx]
        X_val_fold, Y_val_fold = X_train[val_idx], Y_train[val_idx]
        
        history = modelo.fit(X_train_fold, Y_train_fold, epochs=30, validation_data=(X_val_fold, Y_val_fold), callbacks=[early_stopping, reduce_lr])
        holder.append(modelo.evaluate(X_val_fold, Y_val_fold, verbose=0))

        # Previsão e cálculo das métricas para o conjunto de validação
        previsoes_val = modelo.predict(X_val_fold)
        previsoes_binarias_val = [1 if x > 0.5 else 0 for x in previsoes_val]

        # Relatório de Classificação para o conjunto de validação
        relatorio_dict = classification_report(Y_val_fold, previsoes_binarias_val, target_names=["Classe 0", "Classe 1"], output_dict=True)
        precision_val = relatorio_dict['macro avg']['precision']
        recall_val = relatorio_dict['macro avg']['recall']
        f1_val = relatorio_dict['macro avg']['f1-score']
        
        # Calcular AUC-ROC
        auc_roc_val = roc_auc_score(Y_val_fold, previsoes_val)
        
        print("Relatório de Classificação (Validação):\n", classification_report(Y_val_fold, previsoes_binarias_val, target_names=["Classe 0", "Classe 1"]))
        print(f"F1: {f1_val:.4f}, Recall: {recall_val:.4f}, Precision: {precision_val:.4f}, AUC-ROC: {auc_roc_val:.4f}")
        metricas_fold.append((f1_val, recall_val, precision_val, auc_roc_val))
        
        # Verificar se este é o melhor modelo com base no F1-score
        if f1_val > melhor_f1_score:
            melhor_f1_score = f1_val
            melhor_model = modelo 
            bf = i
        i += 1
        del modelo

    # Guardar histórico e métricas
    hist.append(history)
    historys.append(hist)
    metricas_por_fold.append(metricas_fold)
    
    end_time = time.time()
    tempo.append(end_time - start_time)
    scores.append(holder)

# Exibir as métricas por fold e por fase
print(metricas_por_fold)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Epoch 1/30
#   7/270 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6022 - loss: 0.7938
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722445123.550196     139 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 56s 121ms/step - accuracy: 0.6602 - loss: 0.6901 - val_accuracy: 0.7362 - val_loss: 0.5355 - learning_rate: 0.0010
# Epoch 2/30
#   7/270 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.7488 - loss: 0.5428
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py:96: UserWarning: Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7265 - loss: 0.5526 - val_accuracy: 0.7425 - val_loss: 0.5238 - learning_rate: 0.0010
# Epoch 3/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7498 - loss: 0.5097 - val_accuracy: 0.7536 - val_loss: 0.5045 - learning_rate: 0.0010
# Epoch 4/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7612 - loss: 0.4903 - val_accuracy: 0.7480 - val_loss: 0.5143 - learning_rate: 0.0010
# Epoch 5/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7700 - loss: 0.4737 - val_accuracy: 0.7541 - val_loss: 0.5143 - learning_rate: 0.0010
# Epoch 6/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7798 - loss: 0.4527 - val_accuracy: 0.7506 - val_loss: 0.5075 - learning_rate: 0.0010
# Epoch 7/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7921 - loss: 0.4395 - val_accuracy: 0.7538 - val_loss: 0.5029 - learning_rate: 0.0010
# Epoch 8/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8011 - loss: 0.4241 - val_accuracy: 0.7443 - val_loss: 0.5300 - learning_rate: 0.0010
# Epoch 9/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8102 - loss: 0.4208 - val_accuracy: 0.7513 - val_loss: 0.5287 - learning_rate: 0.0010
# Epoch 10/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8141 - loss: 0.3966 - val_accuracy: 0.7492 - val_loss: 0.5246 - learning_rate: 0.0010
# Epoch 11/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8144 - loss: 0.4010 - val_accuracy: 0.6623 - val_loss: 0.8397 - learning_rate: 0.0010
# Epoch 12/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8237 - loss: 0.3794 - val_accuracy: 0.7559 - val_loss: 0.5374 - learning_rate: 0.0010
# Epoch 13/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8405 - loss: 0.3679 - val_accuracy: 0.7552 - val_loss: 0.5361 - learning_rate: 0.0010
# Epoch 14/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8409 - loss: 0.3574 - val_accuracy: 0.7329 - val_loss: 0.5650 - learning_rate: 0.0010
# Epoch 15/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8454 - loss: 0.3423 - val_accuracy: 0.7520 - val_loss: 0.5555 - learning_rate: 0.0010
# Epoch 16/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8515 - loss: 0.3362 - val_accuracy: 0.7471 - val_loss: 0.5891 - learning_rate: 0.0010
# Epoch 17/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8586 - loss: 0.3301 - val_accuracy: 0.7401 - val_loss: 0.5596 - learning_rate: 0.0010
# Epoch 18/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.8605 - loss: 0.3228 - val_accuracy: 0.7522 - val_loss: 0.5571 - learning_rate: 0.0010
# Epoch 19/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8511 - loss: 0.3157 - val_accuracy: 0.7534 - val_loss: 0.6221 - learning_rate: 0.0010
# Epoch 20/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8639 - loss: 0.3022 - val_accuracy: 0.7413 - val_loss: 0.6010 - learning_rate: 0.0010
# Epoch 21/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8677 - loss: 0.3034 - val_accuracy: 0.7452 - val_loss: 0.6396 - learning_rate: 0.0010
# Epoch 22/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8789 - loss: 0.2790 - val_accuracy: 0.7557 - val_loss: 0.6225 - learning_rate: 0.0010
# Epoch 23/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8819 - loss: 0.2651 - val_accuracy: 0.7494 - val_loss: 0.6381 - learning_rate: 0.0010
# Epoch 24/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.8805 - loss: 0.2726 - val_accuracy: 0.7517 - val_loss: 0.6473 - learning_rate: 0.0010
# Epoch 25/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8982 - loss: 0.2478 - val_accuracy: 0.7431 - val_loss: 0.6441 - learning_rate: 0.0010
# Epoch 26/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.9014 - loss: 0.2430 - val_accuracy: 0.7378 - val_loss: 0.6328 - learning_rate: 0.0010
# Epoch 27/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8984 - loss: 0.2424 - val_accuracy: 0.7513 - val_loss: 0.6370 - learning_rate: 0.0010
# Epoch 28/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.9006 - loss: 0.2430 - val_accuracy: 0.7499 - val_loss: 0.6313 - learning_rate: 0.0010
# Epoch 29/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.9043 - loss: 0.2357 - val_accuracy: 0.7515 - val_loss: 0.6466 - learning_rate: 0.0010
# Epoch 30/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.9050 - loss: 0.2326 - val_accuracy: 0.7297 - val_loss: 0.6769 - learning_rate: 0.0010
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step
# Relatório de Classificação (Validação):
#                precision    recall  f1-score   support
#
#     Classe 0       0.72      0.74      0.73      2102
#     Classe 1       0.74      0.72      0.73      2204
#
#     accuracy                           0.73      4306
#    macro avg       0.73      0.73      0.73      4306
# weighted avg       0.73      0.73      0.73      4306
#
# F1: 0.7296, Recall: 0.7298, Precision: 0.7297, AUC-ROC: 0.8123
# Epoch 1/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 51s 122ms/step - accuracy: 0.6495 - loss: 0.7051 - val_accuracy: 0.7308 - val_loss: 0.5657 - learning_rate: 0.0010
# Epoch 2/30
#   7/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.7895 - loss: 0.4841
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py:96: UserWarning: Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7390 - loss: 0.5407 - val_accuracy: 0.7438 - val_loss: 0.5262 - learning_rate: 0.0010
# Epoch 3/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.7438 - loss: 0.5162 - val_accuracy: 0.7245 - val_loss: 0.5367 - learning_rate: 0.0010
# Epoch 4/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7630 - loss: 0.4847 - val_accuracy: 0.7501 - val_loss: 0.5118 - learning_rate: 0.0010
# Epoch 5/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.7772 - loss: 0.4669 - val_accuracy: 0.7445 - val_loss: 0.5205 - learning_rate: 0.0010
# Epoch 6/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.7961 - loss: 0.4374 - val_accuracy: 0.7408 - val_loss: 0.5235 - learning_rate: 0.0010
# Epoch 7/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.7946 - loss: 0.4362 - val_accuracy: 0.7533 - val_loss: 0.5099 - learning_rate: 0.0010
# Epoch 8/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8117 - loss: 0.4144 - val_accuracy: 0.7491 - val_loss: 0.5223 - learning_rate: 0.0010
# Epoch 9/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8198 - loss: 0.3961 - val_accuracy: 0.7491 - val_loss: 0.5292 - learning_rate: 0.0010
# Epoch 10/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8157 - loss: 0.4053 - val_accuracy: 0.7468 - val_loss: 0.5400 - learning_rate: 0.0010
# Epoch 11/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8163 - loss: 0.3990 - val_accuracy: 0.7463 - val_loss: 0.5770 - learning_rate: 0.0010
# Epoch 12/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8232 - loss: 0.3879 - val_accuracy: 0.7533 - val_loss: 0.5383 - learning_rate: 0.0010
# Epoch 13/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8334 - loss: 0.3736 - val_accuracy: 0.7503 - val_loss: 0.5445 - learning_rate: 0.0010
# Epoch 14/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8378 - loss: 0.3600 - val_accuracy: 0.7489 - val_loss: 0.5651 - learning_rate: 0.0010
# Epoch 15/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8457 - loss: 0.3565 - val_accuracy: 0.7273 - val_loss: 0.5816 - learning_rate: 0.0010
# Epoch 16/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8460 - loss: 0.3413 - val_accuracy: 0.7510 - val_loss: 0.5984 - learning_rate: 0.0010
# Epoch 17/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8618 - loss: 0.3241 - val_accuracy: 0.7508 - val_loss: 0.6175 - learning_rate: 0.0010
# Epoch 18/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.8693 - loss: 0.3200 - val_accuracy: 0.7480 - val_loss: 0.6191 - learning_rate: 0.0010
# Epoch 19/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8712 - loss: 0.3080 - val_accuracy: 0.7415 - val_loss: 0.6539 - learning_rate: 0.0010
# Epoch 20/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8790 - loss: 0.2854 - val_accuracy: 0.7489 - val_loss: 0.6255 - learning_rate: 0.0010
# Epoch 21/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8682 - loss: 0.3020 - val_accuracy: 0.7510 - val_loss: 0.6374 - learning_rate: 0.0010
# Epoch 22/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8780 - loss: 0.2893 - val_accuracy: 0.7496 - val_loss: 0.6012 - learning_rate: 0.0010
# Epoch 23/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8808 - loss: 0.2780 - val_accuracy: 0.7515 - val_loss: 0.6436 - learning_rate: 0.0010
# Epoch 24/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8863 - loss: 0.2693 - val_accuracy: 0.7477 - val_loss: 0.6956 - learning_rate: 0.0010
# Epoch 25/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8926 - loss: 0.2498 - val_accuracy: 0.7429 - val_loss: 0.6599 - learning_rate: 0.0010
# Epoch 26/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8909 - loss: 0.2530 - val_accuracy: 0.7384 - val_loss: 0.6661 - learning_rate: 0.0010
# Epoch 27/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.9012 - loss: 0.2281 - val_accuracy: 0.7182 - val_loss: 0.7076 - learning_rate: 0.0010
# Epoch 28/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8987 - loss: 0.2423 - val_accuracy: 0.7333 - val_loss: 0.7357 - learning_rate: 0.0010
# Epoch 29/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8936 - loss: 0.2526 - val_accuracy: 0.7324 - val_loss: 0.6985 - learning_rate: 0.0010
# Epoch 30/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.9061 - loss: 0.2277 - val_accuracy: 0.7473 - val_loss: 0.7023 - learning_rate: 0.0010
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 60ms/step
# Relatório de Classificação (Validação):
#                precision    recall  f1-score   support
#
#     Classe 0       0.74      0.73      0.74      2101
#     Classe 1       0.75      0.76      0.75      2204
#
#     accuracy                           0.75      4305
#    macro avg       0.75      0.75      0.75      4305
# weighted avg       0.75      0.75      0.75      4305
#
# F1: 0.7470, Recall: 0.7470, Precision: 0.7472, AUC-ROC: 0.8244
# Epoch 1/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 45s 99ms/step - accuracy: 0.6513 - loss: 0.7064 - val_accuracy: 0.6997 - val_loss: 0.6541 - learning_rate: 0.0010
# Epoch 2/30
#   7/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.7903 - loss: 0.4607
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py:96: UserWarning: Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.7278 - loss: 0.5450 - val_accuracy: 0.7261 - val_loss: 0.5446 - learning_rate: 0.0010
# Epoch 3/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.7475 - loss: 0.5146 - val_accuracy: 0.7510 - val_loss: 0.5108 - learning_rate: 0.0010
# Epoch 4/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.7646 - loss: 0.4943 - val_accuracy: 0.7410 - val_loss: 0.5325 - learning_rate: 0.0010
# Epoch 5/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.7810 - loss: 0.4603 - val_accuracy: 0.7301 - val_loss: 0.5538 - learning_rate: 0.0010
# Epoch 6/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.7875 - loss: 0.4453 - val_accuracy: 0.7352 - val_loss: 0.5223 - learning_rate: 0.0010
# Epoch 7/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.7932 - loss: 0.4449 - val_accuracy: 0.7415 - val_loss: 0.5178 - learning_rate: 0.0010
# Epoch 8/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8005 - loss: 0.4264 - val_accuracy: 0.7477 - val_loss: 0.5230 - learning_rate: 0.0010
# Epoch 9/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.8183 - loss: 0.3935 - val_accuracy: 0.7519 - val_loss: 0.5134 - learning_rate: 0.0010
# Epoch 10/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8219 - loss: 0.3990 - val_accuracy: 0.7289 - val_loss: 0.5452 - learning_rate: 0.0010
# Epoch 11/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.8207 - loss: 0.3979 - val_accuracy: 0.7433 - val_loss: 0.5429 - learning_rate: 0.0010
# Epoch 12/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.8337 - loss: 0.3646 - val_accuracy: 0.7461 - val_loss: 0.5547 - learning_rate: 0.0010
# Epoch 13/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.8373 - loss: 0.3628 - val_accuracy: 0.7331 - val_loss: 0.5587 - learning_rate: 0.0010
# Epoch 14/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.8421 - loss: 0.3537 - val_accuracy: 0.7206 - val_loss: 0.5721 - learning_rate: 0.0010
# Epoch 15/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.8525 - loss: 0.3443 - val_accuracy: 0.7512 - val_loss: 0.5930 - learning_rate: 0.0010
# Epoch 16/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.8458 - loss: 0.3442 - val_accuracy: 0.7461 - val_loss: 0.5907 - learning_rate: 0.0010
# Epoch 17/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.8601 - loss: 0.3278 - val_accuracy: 0.7401 - val_loss: 0.5910 - learning_rate: 0.0010
# Epoch 18/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.8647 - loss: 0.3158 - val_accuracy: 0.7456 - val_loss: 0.6114 - learning_rate: 0.0010
# Epoch 19/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.8699 - loss: 0.3099 - val_accuracy: 0.7440 - val_loss: 0.5877 - learning_rate: 0.0010
# Epoch 20/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8649 - loss: 0.3097 - val_accuracy: 0.7454 - val_loss: 0.6458 - learning_rate: 0.0010
# Epoch 21/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.8742 - loss: 0.2928 - val_accuracy: 0.7405 - val_loss: 0.6213 - learning_rate: 0.0010
# Epoch 22/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8800 - loss: 0.2746 - val_accuracy: 0.7329 - val_loss: 0.6317 - learning_rate: 0.0010
# Epoch 23/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8758 - loss: 0.2939 - val_accuracy: 0.7398 - val_loss: 0.6223 - learning_rate: 0.0010
# Epoch 24/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8919 - loss: 0.2673 - val_accuracy: 0.7364 - val_loss: 0.6483 - learning_rate: 0.0010
# Epoch 25/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8941 - loss: 0.2583 - val_accuracy: 0.7508 - val_loss: 0.6304 - learning_rate: 0.0010
# Epoch 26/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8928 - loss: 0.2499 - val_accuracy: 0.7350 - val_loss: 0.6393 - learning_rate: 0.0010
# Epoch 27/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8935 - loss: 0.2498 - val_accuracy: 0.7510 - val_loss: 0.7109 - learning_rate: 0.0010
# Epoch 28/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.8965 - loss: 0.2411 - val_accuracy: 0.7403 - val_loss: 0.6987 - learning_rate: 0.0010
# Epoch 29/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.9012 - loss: 0.2337 - val_accuracy: 0.7480 - val_loss: 0.7068 - learning_rate: 0.0010
# Epoch 30/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.9024 - loss: 0.2355 - val_accuracy: 0.7487 - val_loss: 0.7042 - learning_rate: 0.0010
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 57ms/step
# Relatório de Classificação (Validação):
#                precision    recall  f1-score   support
#
#     Classe 0       0.74      0.74      0.74      2101
#     Classe 1       0.75      0.76      0.75      2204
#
#     accuracy                           0.75      4305
#    macro avg       0.75      0.75      0.75      4305
# weighted avg       0.75      0.75      0.75      4305
#
# F1: 0.7485, Recall: 0.7485, Precision: 0.7485, AUC-ROC: 0.8240
# [[(0.7296459225175966, 0.7298249787170115, 0.7296964663243733, 0.8122860908546178), (0.74704348322005, 0.7469812793320267, 0.7471603003944027, 0.8244361858625786), (0.7485031162221945, 0.7484870224273119, 0.748522122269139, 0.8239894838772652)]]

# %%
model = melhor_model

# %%
Y_test = np.array(Y_test)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Certifique-se de que X_test e Y_test tenham a forma correta
print(f"Forma de X_test: {X_test.shape}")
print(f"Forma de Y_test: {Y_test.shape}")

# Verifique se X_test não está vazio
if X_test.size == 0:
    raise ValueError("X_test está vazio")

# Realize a predição
previsoes = model.predict(X_test)

# Verifique a forma das previsões
print(f"Forma das previsões: {previsoes.shape}")

# Converta as previsões para binário
previsoes_binarias = [1 if x > 0.5 else 0 for x in previsoes]

# Avaliação da acurácia
acuracia = accuracy_score(Y_test, previsoes_binarias)
print(f"Acurácia no conjunto de teste: {acuracia}")

# Matriz de Confusão
matriz_confusao = confusion_matrix(Y_test, previsoes_binarias)
print("Matriz de Confusão:\n", matriz_confusao)

# Plot da Matriz de Confusão
plt.figure(figsize=(10, 7))
sns.heatmap(matriz_confusao, annot=True, fmt="d", cmap="Blues", xticklabels=["Classe Negativa", "Classe Positiva"], yticklabels=["Classe Negativa", "Classe Positiva"])
plt.title('Matriz de Confusão')
plt.ylabel('Valor Real')
plt.xlabel('Valor Previsto')
plt.show()

# Relatório de Classificação
relatorio_classificacao = classification_report(Y_test, previsoes_binarias, target_names=["Classe 0", "Classe 1"])
print("Relatório de Classificação:\n", relatorio_classificacao)
# Out:
# Forma de X_test: (1990, 100, 100, 3)
# Forma de Y_test: (1990,)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step
# Forma das previsões: (1990, 1)
# Acurácia no conjunto de teste: 0.7437185929648241
# Matriz de Confusão:
#  [[1185  377]
#  [ 133  295]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#     Classe 0       0.90      0.76      0.82      1562
#     Classe 1       0.44      0.69      0.54       428
#
#     accuracy                           0.74      1990
#    macro avg       0.67      0.72      0.68      1990
# weighted avg       0.80      0.74      0.76      1990

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

def train_model(model, X_train, Y_train, EPOCHS=30):
    # Usando 'val_accuracy' em vez de 'val_acc'
    early_stop = EarlyStopping(monitor='val_accuracy', patience=10,verbose=1,
                               mode='max', restore_best_weights=True)

    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=5,
                                  verbose=1, mode='max', min_lr=1e-5)

    history = model.fit(X_train,
                        Y_train,
                        validation_split=0.2,
                        batch_size=16,
                        epochs=EPOCHS,
                        callbacks=[reduce_lr, early_stop])
    return history

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

def create_inceptionv3_L():
    base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(100, 100, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.25)(x)
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.25)(x)
    x = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    predictions = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01))(x)
    model = Model(inputs=base_model.input, outputs=predictions)

    # Define o número de camadas a congelar
    # Neste caso, congelar as primeiras 249 camadas e treinar o restante
    for layer in base_model.layers[:249]:
        layer.trainable = False
    for layer in base_model.layers[249:]:
        layer.trainable = True

    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np  # Importe a biblioteca NumPy

# Listas para armazenar as métricas de cada iteração
accuracies = []
precisions = []
recalls = []
f1_scores = []
historys = []
if(bf==0):
    treinox = x_train_1
    treinoy = y_train_1
    print("melor fold = 1")
elif(bf==1):
    treinox = x_train_2
    treinoy = y_train_2
    print("melor fold = 2")
else:
    treinox = x_train_3
    treinoy = y_train_3
    print("melor fold = 3")

for i in range(10):
    print("OIBOMDIA",i)
    tf.keras.backend.clear_session()
    model = create_InceptionV3()
    historys.append(train_model(model, treinox, treinoy, 30))

    previsoes = model.predict(X_test)
    previsoes_binarias = [1 if x > 0.5 else 0 for x in previsoes]

    # Adiciona a acurácia à lista
    acuracia = accuracy_score(Y_test, previsoes_binarias)
    accuracies.append(acuracia)

    # Calcula e adiciona precisão, recall e f1-score à suas respectivas listas
    relatorio_classificacao = classification_report(Y_test, previsoes_binarias, target_names=["Classe 0", "Classe 1"], output_dict=True)
    # Capturando os valores individuais de precisão, recall e F1-score para a classe '1'
    precisao_classe_1 = relatorio_classificacao['macro avg']['precision']
    recall_classe_1 = relatorio_classificacao['macro avg']['recall']
    f1_score_classe_1 = relatorio_classificacao['macro avg']['f1-score']

    print(f"Precisão : {precisao_classe_1}")
    print(f"Recall : {recall_classe_1}")
    print(f"F1-Score : {f1_score_classe_1}")

    precisions.append(precisao_classe_1)
    recalls.append(recall_classe_1)
    f1_scores.append(f1_score_classe_1)


# Calcula a média de cada métrica
acuracia_media = np.mean(accuracies)
precisao_media = np.mean(precisions)
recall_medio = np.mean(recalls)
f1_score_medio = np.mean(f1_scores)

# Calcula o desvio padrão de cada métrica
acuracia_dp = np.std(accuracies)
precisao_dp = np.std(precisions)
recall_dp = np.std(recalls)
f1_score_dp = np.std(f1_scores)

# Exibe os resultados
print(f"Acurácia média: {acuracia_media} ± {acuracia_dp}")
print(f"Precisão média: {precisao_media} ± {precisao_dp}")
print(f"Recall médio: {recall_medio} ± {recall_dp}")
print(f"F1-Score médio: {f1_score_medio} ± {f1_score_dp}")

# Opção para plotar a matriz de confusão da última iteração
cm = confusion_matrix(Y_test, previsoes_binarias)
sns.heatmap(cm, annot=True, fmt="d")
plt.xlabel('Predito')
plt.ylabel('Verdadeiro')
plt.show()

import matplotlib.pyplot as plt

# Configuração do gráfico de Acurácia
plt.figure(figsize=(14, 5))

# Gráfico de Acurácia por Época para cada history
plt.subplot(1, 2, 1)  # 1 linha, 2 colunas, posição 1
for history in historys:
    plt.plot(history.history['accuracy'], label='Acurácia (treino)')
    plt.plot(history.history['val_accuracy'], label='Acurácia (validação)')
plt.title('Acurácia por Época')
plt.xlabel('Época')
plt.ylabel('Acurácia')
plt.legend()

# Configuração do gráfico de Loss
plt.subplot(1, 2, 2)  # 1 linha, 2 colunas, posição 2
for history in historys:
    plt.plot(history.history['loss'], label='Loss (treino)')
    plt.plot(history.history['val_loss'], label='Loss (validação)')
plt.title('Loss por Época')
plt.xlabel('Época')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# melor fold = 3
# OIBOMDIA 0
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 58s 82ms/step - accuracy: 0.6414 - loss: 0.7315 - val_accuracy: 0.6732 - val_loss: 0.6099 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7090 - loss: 0.5751 - val_accuracy: 0.7185 - val_loss: 0.5595 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7346 - loss: 0.5224 - val_accuracy: 0.7145 - val_loss: 0.5537 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7511 - loss: 0.5079 - val_accuracy: 0.7348 - val_loss: 0.5505 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7675 - loss: 0.4835 - val_accuracy: 0.7179 - val_loss: 0.5438 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7805 - loss: 0.4586 - val_accuracy: 0.7284 - val_loss: 0.5607 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7809 - loss: 0.4555 - val_accuracy: 0.7156 - val_loss: 0.5623 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7900 - loss: 0.4507 - val_accuracy: 0.7156 - val_loss: 0.5674 - learning_rate: 0.0010
# Epoch 9/30
# 428/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7819 - loss: 0.4574
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7819 - loss: 0.4574 - val_accuracy: 0.7278 - val_loss: 0.5809 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8087 - loss: 0.4184 - val_accuracy: 0.7324 - val_loss: 0.5526 - learning_rate: 1.0000e-04
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8361 - loss: 0.3781 - val_accuracy: 0.7295 - val_loss: 0.5625 - learning_rate: 1.0000e-04
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8358 - loss: 0.3767 - val_accuracy: 0.7342 - val_loss: 0.5760 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8395 - loss: 0.3573 - val_accuracy: 0.7330 - val_loss: 0.5867 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8438 - loss: 0.3458 - val_accuracy: 0.7365 - val_loss: 0.5961 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8462 - loss: 0.3346 - val_accuracy: 0.7330 - val_loss: 0.6060 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8603 - loss: 0.3223 - val_accuracy: 0.7342 - val_loss: 0.6144 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8537 - loss: 0.3284 - val_accuracy: 0.7319 - val_loss: 0.6267 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8663 - loss: 0.3166 - val_accuracy: 0.7324 - val_loss: 0.6357 - learning_rate: 1.0000e-04
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8727 - loss: 0.2987
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8727 - loss: 0.2987 - val_accuracy: 0.7295 - val_loss: 0.6375 - learning_rate: 1.0000e-04
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8731 - loss: 0.2951 - val_accuracy: 0.7261 - val_loss: 0.6444 - learning_rate: 1.0000e-05
# Epoch 21/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8791 - loss: 0.2972 - val_accuracy: 0.7266 - val_loss: 0.6423 - learning_rate: 1.0000e-05
# Epoch 22/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8703 - loss: 0.2996 - val_accuracy: 0.7307 - val_loss: 0.6463 - learning_rate: 1.0000e-05
# Epoch 23/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8770 - loss: 0.2866 - val_accuracy: 0.7290 - val_loss: 0.6454 - learning_rate: 1.0000e-05
# Epoch 24/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8716 - loss: 0.2977
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8716 - loss: 0.2976 - val_accuracy: 0.7278 - val_loss: 0.6501 - learning_rate: 1.0000e-05
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 97ms/step
# Precisão : 0.6851353525308218
# Recall : 0.7461602666124187
# F1-Score : 0.697447963800905
# OIBOMDIA 1
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 45s 62ms/step - accuracy: 0.6542 - loss: 0.6928 - val_accuracy: 0.7127 - val_loss: 0.5676 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7221 - loss: 0.5606 - val_accuracy: 0.7220 - val_loss: 0.5654 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7469 - loss: 0.5284 - val_accuracy: 0.7319 - val_loss: 0.5428 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7551 - loss: 0.4953 - val_accuracy: 0.7301 - val_loss: 0.5300 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7758 - loss: 0.4804 - val_accuracy: 0.7324 - val_loss: 0.5381 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7716 - loss: 0.4638 - val_accuracy: 0.7394 - val_loss: 0.5369 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7946 - loss: 0.4516 - val_accuracy: 0.7232 - val_loss: 0.5524 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7983 - loss: 0.4281 - val_accuracy: 0.7359 - val_loss: 0.5307 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7888 - loss: 0.4360 - val_accuracy: 0.7226 - val_loss: 0.5710 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8008 - loss: 0.4331 - val_accuracy: 0.7400 - val_loss: 0.5681 - learning_rate: 0.0010
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8119 - loss: 0.4142 - val_accuracy: 0.7394 - val_loss: 0.5448 - learning_rate: 0.0010
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8158 - loss: 0.4062 - val_accuracy: 0.7237 - val_loss: 0.5749 - learning_rate: 0.0010
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8152 - loss: 0.4116 - val_accuracy: 0.7330 - val_loss: 0.5835 - learning_rate: 0.0010
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8311 - loss: 0.3792 - val_accuracy: 0.7353 - val_loss: 0.5843 - learning_rate: 0.0010
# Epoch 15/30
# 429/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8357 - loss: 0.3663
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8357 - loss: 0.3663 - val_accuracy: 0.7208 - val_loss: 0.5977 - learning_rate: 0.0010
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8525 - loss: 0.3487 - val_accuracy: 0.7324 - val_loss: 0.5890 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8617 - loss: 0.3219 - val_accuracy: 0.7319 - val_loss: 0.6111 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8651 - loss: 0.3145 - val_accuracy: 0.7301 - val_loss: 0.6275 - learning_rate: 1.0000e-04
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8673 - loss: 0.3031 - val_accuracy: 0.7324 - val_loss: 0.6449 - learning_rate: 1.0000e-04
# Epoch 20/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8712 - loss: 0.2976
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8712 - loss: 0.2976 - val_accuracy: 0.7336 - val_loss: 0.6355 - learning_rate: 1.0000e-04
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 98ms/step
# Precisão : 0.6720782752986234
# Recall : 0.743692187107351
# F1-Score : 0.6747974013796798
# OIBOMDIA 2
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 44s 61ms/step - accuracy: 0.6467 - loss: 0.6932 - val_accuracy: 0.7197 - val_loss: 0.5811 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7252 - loss: 0.5555 - val_accuracy: 0.7232 - val_loss: 0.5583 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7474 - loss: 0.5090 - val_accuracy: 0.7127 - val_loss: 0.5508 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7589 - loss: 0.4927 - val_accuracy: 0.7214 - val_loss: 0.5483 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7685 - loss: 0.4955 - val_accuracy: 0.7272 - val_loss: 0.5374 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7696 - loss: 0.4782 - val_accuracy: 0.7208 - val_loss: 0.5596 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7835 - loss: 0.4679 - val_accuracy: 0.7272 - val_loss: 0.5674 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7888 - loss: 0.4625 - val_accuracy: 0.7220 - val_loss: 0.5455 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7974 - loss: 0.4287 - val_accuracy: 0.7411 - val_loss: 0.5632 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8098 - loss: 0.4193 - val_accuracy: 0.7353 - val_loss: 0.5681 - learning_rate: 0.0010
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8141 - loss: 0.4130 - val_accuracy: 0.7324 - val_loss: 0.5534 - learning_rate: 0.0010
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8161 - loss: 0.4061 - val_accuracy: 0.7174 - val_loss: 0.5699 - learning_rate: 0.0010
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8267 - loss: 0.3915 - val_accuracy: 0.7365 - val_loss: 0.5702 - learning_rate: 0.0010
# Epoch 14/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8262 - loss: 0.3801
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.8262 - loss: 0.3801 - val_accuracy: 0.7162 - val_loss: 0.6249 - learning_rate: 0.0010
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8341 - loss: 0.3681 - val_accuracy: 0.7284 - val_loss: 0.5902 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8595 - loss: 0.3272 - val_accuracy: 0.7284 - val_loss: 0.5926 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8678 - loss: 0.3147 - val_accuracy: 0.7342 - val_loss: 0.6029 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8544 - loss: 0.3205 - val_accuracy: 0.7295 - val_loss: 0.6026 - learning_rate: 1.0000e-04
# Epoch 19/30
# 429/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8731 - loss: 0.3060
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8731 - loss: 0.3060 - val_accuracy: 0.7377 - val_loss: 0.6204 - learning_rate: 1.0000e-04
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 98ms/step
# Precisão : 0.6765276075863709
# Recall : 0.7454377924300262
# F1-Score : 0.6833257000100936
# OIBOMDIA 3
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 45s 61ms/step - accuracy: 0.6466 - loss: 0.7129 - val_accuracy: 0.6999 - val_loss: 0.5791 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7161 - loss: 0.5648 - val_accuracy: 0.7098 - val_loss: 0.5623 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.7402 - loss: 0.5172 - val_accuracy: 0.7040 - val_loss: 0.5473 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.7555 - loss: 0.4991 - val_accuracy: 0.7261 - val_loss: 0.5451 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7664 - loss: 0.4843 - val_accuracy: 0.7197 - val_loss: 0.5701 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7795 - loss: 0.4695 - val_accuracy: 0.7441 - val_loss: 0.5407 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7700 - loss: 0.4668 - val_accuracy: 0.7168 - val_loss: 0.5529 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7888 - loss: 0.4597 - val_accuracy: 0.7400 - val_loss: 0.5385 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7951 - loss: 0.4364 - val_accuracy: 0.7098 - val_loss: 0.5687 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8059 - loss: 0.4263 - val_accuracy: 0.6889 - val_loss: 0.6265 - learning_rate: 0.0010
# Epoch 11/30
# 429/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7973 - loss: 0.4343
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7973 - loss: 0.4344 - val_accuracy: 0.7197 - val_loss: 0.6189 - learning_rate: 0.0010
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8257 - loss: 0.3909 - val_accuracy: 0.7313 - val_loss: 0.5573 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8393 - loss: 0.3603 - val_accuracy: 0.7237 - val_loss: 0.5702 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8574 - loss: 0.3452 - val_accuracy: 0.7266 - val_loss: 0.5868 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8578 - loss: 0.3391 - val_accuracy: 0.7330 - val_loss: 0.5934 - learning_rate: 1.0000e-04
# Epoch 16/30
# 428/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8558 - loss: 0.3361
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8558 - loss: 0.3360 - val_accuracy: 0.7290 - val_loss: 0.6095 - learning_rate: 1.0000e-04
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 99ms/step
# Precisão : 0.6707264542175899
# Recall : 0.7418837579427286
# F1-Score : 0.6731710335897632
# OIBOMDIA 4
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 45s 62ms/step - accuracy: 0.6509 - loss: 0.6886 - val_accuracy: 0.6994 - val_loss: 0.5836 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7142 - loss: 0.5662 - val_accuracy: 0.7272 - val_loss: 0.5602 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7520 - loss: 0.5163 - val_accuracy: 0.7295 - val_loss: 0.5473 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7511 - loss: 0.5100 - val_accuracy: 0.7348 - val_loss: 0.5386 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7503 - loss: 0.4900 - val_accuracy: 0.7168 - val_loss: 0.5737 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7773 - loss: 0.4587 - val_accuracy: 0.7336 - val_loss: 0.5341 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7852 - loss: 0.4590 - val_accuracy: 0.7272 - val_loss: 0.5364 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7903 - loss: 0.4426 - val_accuracy: 0.7203 - val_loss: 0.5578 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7934 - loss: 0.4380
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7934 - loss: 0.4381 - val_accuracy: 0.7150 - val_loss: 0.5546 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8210 - loss: 0.4048 - val_accuracy: 0.7382 - val_loss: 0.5430 - learning_rate: 1.0000e-04
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8379 - loss: 0.3732 - val_accuracy: 0.7371 - val_loss: 0.5542 - learning_rate: 1.0000e-04
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8421 - loss: 0.3594 - val_accuracy: 0.7342 - val_loss: 0.5723 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8519 - loss: 0.3431 - val_accuracy: 0.7429 - val_loss: 0.5826 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8475 - loss: 0.3422 - val_accuracy: 0.7261 - val_loss: 0.5887 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8554 - loss: 0.3341 - val_accuracy: 0.7330 - val_loss: 0.5962 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8529 - loss: 0.3293 - val_accuracy: 0.7301 - val_loss: 0.6064 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8641 - loss: 0.3145 - val_accuracy: 0.7295 - val_loss: 0.6142 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8633 - loss: 0.3164
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8633 - loss: 0.3164 - val_accuracy: 0.7330 - val_loss: 0.6179 - learning_rate: 1.0000e-04
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8688 - loss: 0.3043 - val_accuracy: 0.7324 - val_loss: 0.6237 - learning_rate: 1.0000e-05
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8703 - loss: 0.2956 - val_accuracy: 0.7307 - val_loss: 0.6266 - learning_rate: 1.0000e-05
# Epoch 21/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8691 - loss: 0.2980 - val_accuracy: 0.7336 - val_loss: 0.6285 - learning_rate: 1.0000e-05
# Epoch 22/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8819 - loss: 0.2829 - val_accuracy: 0.7301 - val_loss: 0.6266 - learning_rate: 1.0000e-05
# Epoch 23/30
# 428/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8718 - loss: 0.3019
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.8719 - loss: 0.3019 - val_accuracy: 0.7313 - val_loss: 0.6308 - learning_rate: 1.0000e-05
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 98ms/step
# Precisão : 0.6720115563998987
# Recall : 0.7348444960331231
# F1-Score : 0.6806019577489737
# OIBOMDIA 5
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 45s 62ms/step - accuracy: 0.6405 - loss: 0.7088 - val_accuracy: 0.7005 - val_loss: 0.5804 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7132 - loss: 0.5642 - val_accuracy: 0.7232 - val_loss: 0.5446 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7409 - loss: 0.5216 - val_accuracy: 0.7261 - val_loss: 0.5410 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7578 - loss: 0.4945 - val_accuracy: 0.7365 - val_loss: 0.5275 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7544 - loss: 0.4923 - val_accuracy: 0.7388 - val_loss: 0.5352 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7817 - loss: 0.4614 - val_accuracy: 0.7208 - val_loss: 0.5534 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7925 - loss: 0.4527 - val_accuracy: 0.7284 - val_loss: 0.5539 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7868 - loss: 0.4610 - val_accuracy: 0.7458 - val_loss: 0.5422 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7964 - loss: 0.4402 - val_accuracy: 0.7330 - val_loss: 0.5730 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8011 - loss: 0.4204 - val_accuracy: 0.7429 - val_loss: 0.5482 - learning_rate: 0.0010
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8191 - loss: 0.4046 - val_accuracy: 0.7382 - val_loss: 0.5899 - learning_rate: 0.0010
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8175 - loss: 0.3965 - val_accuracy: 0.7295 - val_loss: 0.5735 - learning_rate: 0.0010
# Epoch 13/30
# 429/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8311 - loss: 0.3789
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8311 - loss: 0.3790 - val_accuracy: 0.7034 - val_loss: 0.5961 - learning_rate: 0.0010
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8353 - loss: 0.3702 - val_accuracy: 0.7313 - val_loss: 0.5752 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8383 - loss: 0.3670 - val_accuracy: 0.7336 - val_loss: 0.5863 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8444 - loss: 0.3442 - val_accuracy: 0.7330 - val_loss: 0.5924 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8615 - loss: 0.3220 - val_accuracy: 0.7319 - val_loss: 0.6088 - learning_rate: 1.0000e-04
# Epoch 18/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8527 - loss: 0.3270
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8527 - loss: 0.3269 - val_accuracy: 0.7313 - val_loss: 0.6229 - learning_rate: 1.0000e-04
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 97ms/step
# Precisão : 0.6792253161974704
# Recall : 0.752318498929003
# F1-Score : 0.6841417412064605
# OIBOMDIA 6
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 44s 61ms/step - accuracy: 0.6580 - loss: 0.6988 - val_accuracy: 0.7011 - val_loss: 0.5725 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7068 - loss: 0.5637 - val_accuracy: 0.7162 - val_loss: 0.5513 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7370 - loss: 0.5167 - val_accuracy: 0.7243 - val_loss: 0.5431 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7500 - loss: 0.5022 - val_accuracy: 0.7243 - val_loss: 0.5513 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7757 - loss: 0.4691 - val_accuracy: 0.7319 - val_loss: 0.5286 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7709 - loss: 0.4747 - val_accuracy: 0.7330 - val_loss: 0.5333 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7900 - loss: 0.4499 - val_accuracy: 0.7249 - val_loss: 0.5674 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7869 - loss: 0.4560 - val_accuracy: 0.7400 - val_loss: 0.5486 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7972 - loss: 0.4401 - val_accuracy: 0.7261 - val_loss: 0.5838 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8094 - loss: 0.4210 - val_accuracy: 0.7237 - val_loss: 0.5610 - learning_rate: 0.0010
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8108 - loss: 0.4243 - val_accuracy: 0.7313 - val_loss: 0.5738 - learning_rate: 0.0010
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8127 - loss: 0.4215 - val_accuracy: 0.7359 - val_loss: 0.5683 - learning_rate: 0.0010
# Epoch 13/30
# 429/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8194 - loss: 0.3996
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8193 - loss: 0.3997 - val_accuracy: 0.7139 - val_loss: 0.5729 - learning_rate: 0.0010
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8277 - loss: 0.3940 - val_accuracy: 0.7330 - val_loss: 0.5717 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8331 - loss: 0.3721 - val_accuracy: 0.7382 - val_loss: 0.5830 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8541 - loss: 0.3356 - val_accuracy: 0.7330 - val_loss: 0.5971 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8561 - loss: 0.3215 - val_accuracy: 0.7382 - val_loss: 0.6036 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8561 - loss: 0.3309
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8561 - loss: 0.3309 - val_accuracy: 0.7359 - val_loss: 0.6136 - learning_rate: 1.0000e-04
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 100ms/step
# Precisão : 0.6794177134341068
# Recall : 0.7521105819282731
# F1-Score : 0.6847369627548429
# OIBOMDIA 7
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 45s 62ms/step - accuracy: 0.6428 - loss: 0.7028 - val_accuracy: 0.7185 - val_loss: 0.5590 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7249 - loss: 0.5547 - val_accuracy: 0.6999 - val_loss: 0.5685 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7398 - loss: 0.5184 - val_accuracy: 0.7133 - val_loss: 0.5519 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7492 - loss: 0.4976 - val_accuracy: 0.7371 - val_loss: 0.5387 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7804 - loss: 0.4707 - val_accuracy: 0.7348 - val_loss: 0.5429 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7820 - loss: 0.4599 - val_accuracy: 0.7382 - val_loss: 0.5438 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7860 - loss: 0.4522 - val_accuracy: 0.7150 - val_loss: 0.5639 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7892 - loss: 0.4503 - val_accuracy: 0.7284 - val_loss: 0.5454 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8025 - loss: 0.4330 - val_accuracy: 0.7359 - val_loss: 0.5557 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8014 - loss: 0.4232 - val_accuracy: 0.7365 - val_loss: 0.5676 - learning_rate: 0.0010
# Epoch 11/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8050 - loss: 0.4156
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8050 - loss: 0.4156 - val_accuracy: 0.7121 - val_loss: 0.5653 - learning_rate: 0.0010
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8195 - loss: 0.3989 - val_accuracy: 0.7295 - val_loss: 0.5700 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8412 - loss: 0.3597 - val_accuracy: 0.7388 - val_loss: 0.5727 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8399 - loss: 0.3555 - val_accuracy: 0.7278 - val_loss: 0.5844 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8595 - loss: 0.3326 - val_accuracy: 0.7319 - val_loss: 0.6008 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8553 - loss: 0.3357 - val_accuracy: 0.7371 - val_loss: 0.6056 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8724 - loss: 0.3082 - val_accuracy: 0.7290 - val_loss: 0.6226 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8707 - loss: 0.3037
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8707 - loss: 0.3037 - val_accuracy: 0.7359 - val_loss: 0.6286 - learning_rate: 1.0000e-04
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8736 - loss: 0.2995 - val_accuracy: 0.7353 - val_loss: 0.6275 - learning_rate: 1.0000e-05
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8742 - loss: 0.2955 - val_accuracy: 0.7353 - val_loss: 0.6324 - learning_rate: 1.0000e-05
# Epoch 21/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8630 - loss: 0.3173 - val_accuracy: 0.7330 - val_loss: 0.6336 - learning_rate: 1.0000e-05
# Epoch 22/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8695 - loss: 0.3009 - val_accuracy: 0.7342 - val_loss: 0.6343 - learning_rate: 1.0000e-05
# Epoch 23/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8708 - loss: 0.2984
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8708 - loss: 0.2984 - val_accuracy: 0.7319 - val_loss: 0.6381 - learning_rate: 1.0000e-05
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 98ms/step
# Precisão : 0.67534601631036
# Recall : 0.7446854021324207
# F1-Score : 0.6814041777829332
# OIBOMDIA 8
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 45s 62ms/step - accuracy: 0.6404 - loss: 0.6973 - val_accuracy: 0.7052 - val_loss: 0.5833 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7318 - loss: 0.5452 - val_accuracy: 0.7220 - val_loss: 0.5514 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7454 - loss: 0.5196 - val_accuracy: 0.7324 - val_loss: 0.5388 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7569 - loss: 0.4979 - val_accuracy: 0.7301 - val_loss: 0.5592 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7700 - loss: 0.4725 - val_accuracy: 0.7330 - val_loss: 0.5385 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7805 - loss: 0.4675 - val_accuracy: 0.7319 - val_loss: 0.5392 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7776 - loss: 0.4668 - val_accuracy: 0.7353 - val_loss: 0.5728 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7914 - loss: 0.4467 - val_accuracy: 0.7319 - val_loss: 0.6092 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8036 - loss: 0.4357 - val_accuracy: 0.7359 - val_loss: 0.5485 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8002 - loss: 0.4265 - val_accuracy: 0.7324 - val_loss: 0.5542 - learning_rate: 0.0010
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8127 - loss: 0.4044 - val_accuracy: 0.7249 - val_loss: 0.5514 - learning_rate: 0.0010
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8136 - loss: 0.4106 - val_accuracy: 0.7226 - val_loss: 0.5776 - learning_rate: 0.0010
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8095 - loss: 0.4134 - val_accuracy: 0.7261 - val_loss: 0.5826 - learning_rate: 0.0010
# Epoch 14/30
# 428/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8256 - loss: 0.3867
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8256 - loss: 0.3868 - val_accuracy: 0.7255 - val_loss: 0.5728 - learning_rate: 0.0010
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8416 - loss: 0.3637 - val_accuracy: 0.7272 - val_loss: 0.5774 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8504 - loss: 0.3485 - val_accuracy: 0.7243 - val_loss: 0.5902 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8574 - loss: 0.3258 - val_accuracy: 0.7249 - val_loss: 0.6045 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8670 - loss: 0.3068 - val_accuracy: 0.7255 - val_loss: 0.6145 - learning_rate: 1.0000e-04
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8712 - loss: 0.3059
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8712 - loss: 0.3059 - val_accuracy: 0.7295 - val_loss: 0.6154 - learning_rate: 1.0000e-04
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 97ms/step
# Precisão : 0.6626236987696905
# Recall : 0.7394949561429751
# F1-Score : 0.6462066725102058
# OIBOMDIA 9
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 45s 62ms/step - accuracy: 0.6331 - loss: 0.7265 - val_accuracy: 0.7098 - val_loss: 0.5684 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7272 - loss: 0.5476 - val_accuracy: 0.7290 - val_loss: 0.5433 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7466 - loss: 0.5230 - val_accuracy: 0.7272 - val_loss: 0.5449 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7537 - loss: 0.5006 - val_accuracy: 0.7214 - val_loss: 0.5388 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7773 - loss: 0.4812 - val_accuracy: 0.7330 - val_loss: 0.5466 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7767 - loss: 0.4744 - val_accuracy: 0.7336 - val_loss: 0.5275 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7780 - loss: 0.4583 - val_accuracy: 0.7353 - val_loss: 0.5529 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7818 - loss: 0.4597 - val_accuracy: 0.7429 - val_loss: 0.5428 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7975 - loss: 0.4360 - val_accuracy: 0.7290 - val_loss: 0.5562 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7888 - loss: 0.4358 - val_accuracy: 0.7133 - val_loss: 0.5896 - learning_rate: 0.0010
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8173 - loss: 0.4085 - val_accuracy: 0.7348 - val_loss: 0.5951 - learning_rate: 0.0010
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8251 - loss: 0.3919 - val_accuracy: 0.7232 - val_loss: 0.5854 - learning_rate: 0.0010
# Epoch 13/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8224 - loss: 0.3882
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8224 - loss: 0.3883 - val_accuracy: 0.7214 - val_loss: 0.5669 - learning_rate: 0.0010
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8333 - loss: 0.3820 - val_accuracy: 0.7411 - val_loss: 0.5647 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8564 - loss: 0.3476 - val_accuracy: 0.7377 - val_loss: 0.5780 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8482 - loss: 0.3393 - val_accuracy: 0.7330 - val_loss: 0.6016 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8537 - loss: 0.3392 - val_accuracy: 0.7353 - val_loss: 0.6067 - learning_rate: 1.0000e-04
# Epoch 18/30
# 429/431 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8706 - loss: 0.2982
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.8705 - loss: 0.2983 - val_accuracy: 0.7295 - val_loss: 0.6089 - learning_rate: 1.0000e-04
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 98ms/step
# Precisão : 0.659183635477976
# Recall : 0.7302314310672873
# F1-Score : 0.6538013713649087
# Acurácia média: 0.7262311557788944 ± 0.020060009464042697
# Precisão média: 0.6732275626222909 ± 0.007417503032000546
# Recall médio: 0.7430859370325608 ± 0.0065733782811598284
# F1-Score médio: 0.6759634982148766 ± 0.014479447846204942

# %%
#model.save_weights('/kaggle/working/VGG-16.weights.h5')
