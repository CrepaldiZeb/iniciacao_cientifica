# %%
import pickle

# Carregando a variável do arquivo
with open('/kaggle/input/pre-processamentoa/imagens_redimensionadas.pkl', 'rb') as arquivo:
    X = pickle.load(arquivo)

with open('/kaggle/input/pre-processamentoa/y_orig_mod.pkl', 'rb') as arquivo:
    Y = pickle.load(arquivo)

# %%
import numpy as np

unique, counts = np.unique(Y, return_counts=True)
ocorrencias = dict(zip(unique, counts))

print(ocorrencias)
# Out:
# {0: 7866, 1: 2081}

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
for i in range(3):
    ax = plt.subplot(1, 3, i+1)
    img = ((X[i]/255) + 1) / 2
    plt.imshow(img)
    plt.axis('off')
plt.show()

# %%
X = np.array(X)

# %%
print(np.min(X))
print(np.max(X))
X.shape
# Out:
# 0
# 255
# (9947, 100, 100, 3)

# %%
import numpy as np
import cv2

def aplicar_filtro_gaussiano(imagens, tamanho_kernel=(3, 3), sigma=0):
   
    # Cria um array vazio com o mesmo formato das imagens de entrada para armazenar as imagens transformadas
    imagens_transformadas = np.zeros_like(imagens)
    
    # Itera sobre cada imagem no array de entrada
    for i in range(len(imagens)):
        # Aplica o filtro Gaussiano na imagem atual
        filtrada = cv2.GaussianBlur(imagens[i], tamanho_kernel, sigma)
        
        # Armazena a imagem filtrada no array de imagens transformadas
        imagens_transformadas[i] = filtrada
    
    return imagens_transformadas

# %%
X = aplicar_filtro_gaussiano(X)

# %%
print(np.min(X))
print(np.max(X))
X.shape
# Out:
# 0
# 255
# (9947, 100, 100, 3)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
for i in range(3):
    ax = plt.subplot(1, 3, i+1)
    img = ((X[i]/255) + 1) / 2
    plt.imshow(img)
    plt.axis('off')
plt.show()

# %%
from tensorflow.keras.applications.inception_v3 import preprocess_input
X = preprocess_input(X)
# Out:
# 2024-08-03 17:51:42.473643: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-03 17:51:42.473753: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-03 17:51:42.617689: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
print(np.min(X))
print(np.max(X))
X.shape
# Out:
# -1.0
# 1.0
# (9947, 100, 100, 3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
import numpy as np

unique, counts = np.unique(Y_train, return_counts=True)
ocorrencias = dict(zip(unique, counts))
print("Distribuição no conjunto de treino")
print(ocorrencias)

unique, counts = np.unique(Y_test, return_counts=True)
ocorrencias = dict(zip(unique, counts))

print("Distribuição no conjunto de teste")
print(ocorrencias)
# Out:
# Distribuição no conjunto de treino
# {0: 6304, 1: 1653}
# Distribuição no conjunto de teste
# {0: 1562, 1: 428}

# %%
'''import os
import cv2
import albumentations as A
from skimage.io import imread, imsave
from pathlib import Path

# transformações
import albumentations as A

transformacoes = A.Compose([
    A.ShiftScaleRotate(shift_limit=0.2, scale_limit=0.2, rotate_limit=40, p=1),
    A.HorizontalFlip(p=0.5),
])



novas = 10

index = 0
labels = []
x_train = []

for arquivo in X_train:
    imagem = arquivo
    holder = Y_train[index]
    index += 1
    for i in range(novas):
        imagem_transformada = transformacoes(image=imagem)['image']
        labels.append(holder)
        x_train.append(imagem_transformada)
        
import numpy as np


X_train = np.array(x_train)  
Y_train = np.array(labels)  
'''
import numpy as np
import albumentations as A

# Transformações
transformacoes = A.Compose([
    A.Rotate(limit=20),
    A.ShiftScaleRotate(shift_limit=0.2, scale_limit=0.2, rotate_limit=0),
    A.HorizontalFlip(),
    A.RandomScale(scale_limit=0.1),
    A.Resize(width=100, height=100, p=1),  # Garante que todas as imagens tenham o mesmo tamanho
])

novas = 4
labels = []
x_train = []

for index, imagem in enumerate(X_train):
    holder = Y_train[index]
    
    # Redimensionar a imagem original para garantir uniformidade
    imagem_resized = transformacoes(image=imagem)['image']
    
    if Y_train[index] == 0:
        labels.append(holder)
        x_train.append(imagem_resized)
    else:
        for i in range(novas):
            imagem_transformada = transformacoes(image=imagem)['image']
            labels.append(holder)
            x_train.append(imagem_transformada)

# Convertendo as listas para arrays NumPy
X_train = np.stack(x_train)  # Usa np.stack para garantir que as imagens sejam empilhadas corretamente
Y_train = np.array(labels)  # Convertendo para NumPy array

# %%
import numpy as np

unique, counts = np.unique(Y_train, return_counts=True)
ocorrencias = dict(zip(unique, counts))
print("Distribuição no conjunto de treino")
print(ocorrencias)

unique, counts = np.unique(Y_test, return_counts=True)
ocorrencias = dict(zip(unique, counts))

print("Distribuição no conjunto de teste")
print(ocorrencias)
# Out:
# Distribuição no conjunto de treino
# {0: 6304, 1: 6612}
# Distribuição no conjunto de teste
# {0: 1562, 1: 428}

# %%
print(np.min(X_train))
print(np.max(X_train))
# Out:
# -1.0
# 1.0

# %%
# Criando o objeto StratifiedKFold para 3 folds
from sklearn.model_selection import StratifiedKFold
kfold = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Dicionário para armazenar os dados de treino de cada fold
folds = {}

# Dividindo os dados em folds
for i, (train_index, _) in enumerate(kfold.split(X_train, Y_train)):
    folds[f'x_train_{i+1}'] = X_train[train_index]
    folds[f'y_train_{i+1}'] = Y_train[train_index]

# Agora você tem x_train_1, y_train_1, x_train_2, y_train_2, x_train_3, y_train_3 armazenados no dicionário `folds`
x_train_1, y_train_1 = folds['x_train_1'], folds['y_train_1']
x_train_2, y_train_2 = folds['x_train_2'], folds['y_train_2']
x_train_3, y_train_3 = folds['x_train_3'], folds['y_train_3']

# %%
import numpy as np

unique, counts = np.unique(y_train_1, return_counts=True)
ocorrencias = dict(zip(unique, counts))
print("Distribuição no FOLD 1")
print(ocorrencias)

unique, counts = np.unique(y_train_2, return_counts=True)
ocorrencias = dict(zip(unique, counts))

print("Distribuição no FOLD 2")
print(ocorrencias)

unique, counts = np.unique(y_train_3, return_counts=True)
ocorrencias = dict(zip(unique, counts))

print("Distribuição no FOLD 3")
print(ocorrencias)
# Out:
# Distribuição no FOLD 1
# {0: 4202, 1: 4408}
# Distribuição no FOLD 2
# {0: 4203, 1: 4408}
# Distribuição no FOLD 3
# {0: 4203, 1: 4408}

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

def create_inceptionV3_L():
    base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(100, 100, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.25)(x)
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.25)(x)
    x = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    predictions = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01))(x)
    model = Model(inputs=base_model.input, outputs=predictions)

    # Define o número de camadas a congelar
    # Neste caso, congelar as primeiras 249 camadas e treinar o restante
    for layer in base_model.layers[:249]:
        layer.trainable = False
    for layer in base_model.layers[249:]:
        layer.trainable = True

    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report, roc_auc_score
import numpy as np
import time
import tensorflow as tf
from tensorflow.keras.regularizers import l2

scores = []
tempo = []
historys = []
metricas_por_fold = []
melhor_model = None
melhor_f1_score = 0

if(True):
    start_time = time.time()
    tf.keras.backend.clear_session()
    
    n_splits = 3
    hist = []
    holder = []
    metricas_fold = []
    
    kfold = StratifiedKFold(n_splits=n_splits, shuffle=True)
    
    i = 0
    for train_idx, val_idx in kfold.split(X_train, Y_train):
        tf.keras.backend.clear_session()
        early_stopping = EarlyStopping(monitor='val_acc', patience=10, verbose=1, mode='min', restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2, patience=5, verbose=1, mode='min', min_lr=1e-5)
        modelo = create_inceptionV3_L()
        X_train_fold, Y_train_fold = X_train[train_idx], Y_train[train_idx]
        X_val_fold, Y_val_fold = X_train[val_idx], Y_train[val_idx]
        
        history = modelo.fit(X_train_fold, Y_train_fold, epochs=30, validation_data=(X_val_fold, Y_val_fold), callbacks=[early_stopping, reduce_lr])
        holder.append(modelo.evaluate(X_val_fold, Y_val_fold, verbose=0))

        # Previsão e cálculo das métricas para o conjunto de validação
        previsoes_val = modelo.predict(X_val_fold)
        previsoes_binarias_val = [1 if x > 0.5 else 0 for x in previsoes_val]

        # Relatório de Classificação para o conjunto de validação
        relatorio_dict = classification_report(Y_val_fold, previsoes_binarias_val, target_names=["Classe 0", "Classe 1"], output_dict=True)
        precision_val = relatorio_dict['macro avg']['precision']
        recall_val = relatorio_dict['macro avg']['recall']
        f1_val = relatorio_dict['macro avg']['f1-score']
        
        # Calcular AUC-ROC
        auc_roc_val = roc_auc_score(Y_val_fold, previsoes_val)
        
        print("Relatório de Classificação (Validação):\n", classification_report(Y_val_fold, previsoes_binarias_val, target_names=["Classe 0", "Classe 1"]))
        print(f"F1: {f1_val:.4f}, Recall: {recall_val:.4f}, Precision: {precision_val:.4f}, AUC-ROC: {auc_roc_val:.4f}")
        metricas_fold.append((f1_val, recall_val, precision_val, auc_roc_val))
        
        # Verificar se este é o melhor modelo com base no F1-score
        if f1_val > melhor_f1_score:
            melhor_f1_score = f1_val
            melhor_model = modelo 
            bf = i
        i += 1
        del modelo

    # Guardar histórico e métricas
    hist.append(history)
    historys.append(hist)
    metricas_por_fold.append(metricas_fold)
    
    end_time = time.time()
    tempo.append(end_time - start_time)
    scores.append(holder)

# Exibir as métricas por fold e por fase
print(metricas_por_fold)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/30
#   5/270 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.4644 - loss: 14.2893
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722707564.106414     112 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 77s 152ms/step - accuracy: 0.6632 - loss: 9.9391 - val_accuracy: 0.7464 - val_loss: 2.5039 - learning_rate: 0.0010
# Epoch 2/30
#   5/270 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.7436 - loss: 2.4494
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py:96: UserWarning: Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.7797 - loss: 1.8831 - val_accuracy: 0.7120 - val_loss: 1.0342 - learning_rate: 0.0010
# Epoch 3/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8365 - loss: 0.8076 - val_accuracy: 0.7629 - val_loss: 0.6951 - learning_rate: 0.0010
# Epoch 4/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8579 - loss: 0.5904 - val_accuracy: 0.6993 - val_loss: 0.8389 - learning_rate: 0.0010
# Epoch 5/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8931 - loss: 0.4356 - val_accuracy: 0.7712 - val_loss: 0.5915 - learning_rate: 0.0010
# Epoch 6/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8968 - loss: 0.5791 - val_accuracy: 0.7782 - val_loss: 0.6540 - learning_rate: 0.0010
# Epoch 7/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9177 - loss: 0.3668 - val_accuracy: 0.7922 - val_loss: 0.7146 - learning_rate: 0.0010
# Epoch 8/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9302 - loss: 0.3383 - val_accuracy: 0.7069 - val_loss: 1.1241 - learning_rate: 0.0010
# Epoch 9/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9362 - loss: 0.2598 - val_accuracy: 0.7824 - val_loss: 0.5721 - learning_rate: 0.0010
# Epoch 10/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9361 - loss: 0.2379 - val_accuracy: 0.7938 - val_loss: 0.5706 - learning_rate: 0.0010
# Epoch 11/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9381 - loss: 0.2276 - val_accuracy: 0.7975 - val_loss: 0.5608 - learning_rate: 0.0010
# Epoch 12/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9493 - loss: 0.2055 - val_accuracy: 0.7903 - val_loss: 0.5569 - learning_rate: 0.0010
# Epoch 13/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9534 - loss: 0.2001 - val_accuracy: 0.7942 - val_loss: 0.5602 - learning_rate: 0.0010
# Epoch 14/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9461 - loss: 0.2394 - val_accuracy: 0.7854 - val_loss: 0.6554 - learning_rate: 0.0010
# Epoch 15/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9576 - loss: 0.2116 - val_accuracy: 0.7810 - val_loss: 0.6625 - learning_rate: 0.0010
# Epoch 16/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9548 - loss: 0.3272 - val_accuracy: 0.7796 - val_loss: 0.6934 - learning_rate: 0.0010
# Epoch 17/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9613 - loss: 0.1864 - val_accuracy: 0.7596 - val_loss: 0.6484 - learning_rate: 0.0010
# Epoch 18/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9625 - loss: 0.1971 - val_accuracy: 0.7989 - val_loss: 0.5815 - learning_rate: 0.0010
# Epoch 19/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9579 - loss: 0.1968 - val_accuracy: 0.7594 - val_loss: 0.7052 - learning_rate: 0.0010
# Epoch 20/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9689 - loss: 0.1687 - val_accuracy: 0.8000 - val_loss: 0.6259 - learning_rate: 0.0010
# Epoch 21/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9670 - loss: 0.1833 - val_accuracy: 0.7993 - val_loss: 0.6148 - learning_rate: 0.0010
# Epoch 22/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9659 - loss: 0.2853 - val_accuracy: 0.8000 - val_loss: 0.5988 - learning_rate: 0.0010
# Epoch 23/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9663 - loss: 0.1877 - val_accuracy: 0.8079 - val_loss: 0.5782 - learning_rate: 0.0010
# Epoch 24/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9720 - loss: 0.1517 - val_accuracy: 0.7868 - val_loss: 0.7950 - learning_rate: 0.0010
# Epoch 25/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9710 - loss: 0.1607 - val_accuracy: 0.8019 - val_loss: 0.5691 - learning_rate: 0.0010
# Epoch 26/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9653 - loss: 0.2037 - val_accuracy: 0.7815 - val_loss: 0.6236 - learning_rate: 0.0010
# Epoch 27/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9690 - loss: 0.1645 - val_accuracy: 0.8052 - val_loss: 0.5426 - learning_rate: 0.0010
# Epoch 28/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - accuracy: 0.9800 - loss: 0.1413 - val_accuracy: 0.8084 - val_loss: 0.6044 - learning_rate: 0.0010
# Epoch 29/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9723 - loss: 0.1596 - val_accuracy: 0.8045 - val_loss: 0.6038 - learning_rate: 0.0010
# Epoch 30/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9746 - loss: 0.1497 - val_accuracy: 0.7901 - val_loss: 0.6121 - learning_rate: 0.0010
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 57ms/step
# Relatório de Classificação (Validação):
#                precision    recall  f1-score   support
#
#     Classe 0       0.83      0.71      0.77      2102
#     Classe 1       0.76      0.86      0.81      2204
#
#     accuracy                           0.79      4306
#    macro avg       0.80      0.79      0.79      4306
# weighted avg       0.80      0.79      0.79      4306
#
# F1: 0.7882, Recall: 0.7883, Precision: 0.7962, AUC-ROC: 0.8659
# Epoch 1/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 70s 155ms/step - accuracy: 0.6584 - loss: 9.8649 - val_accuracy: 0.7424 - val_loss: 2.3440 - learning_rate: 0.0010
# Epoch 2/30
#   6/270 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.7929 - loss: 2.2413
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py:96: UserWarning: Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.7897 - loss: 1.6903 - val_accuracy: 0.7779 - val_loss: 0.8311 - learning_rate: 0.0010
# Epoch 3/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8436 - loss: 0.6120 - val_accuracy: 0.7475 - val_loss: 0.6674 - learning_rate: 0.0010
# Epoch 4/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8774 - loss: 0.4212 - val_accuracy: 0.7326 - val_loss: 0.5759 - learning_rate: 0.0010
# Epoch 5/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8959 - loss: 0.3332 - val_accuracy: 0.7749 - val_loss: 0.5576 - learning_rate: 0.0010
# Epoch 6/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9052 - loss: 0.3077 - val_accuracy: 0.7956 - val_loss: 0.5836 - learning_rate: 0.0010
# Epoch 7/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9256 - loss: 0.2963 - val_accuracy: 0.7744 - val_loss: 0.6573 - learning_rate: 0.0010
# Epoch 8/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9129 - loss: 0.4396 - val_accuracy: 0.7703 - val_loss: 0.6087 - learning_rate: 0.0010
# Epoch 9/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9383 - loss: 0.2327 - val_accuracy: 0.7893 - val_loss: 0.8642 - learning_rate: 0.0010
# Epoch 10/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9356 - loss: 0.3808 - val_accuracy: 0.7849 - val_loss: 0.5591 - learning_rate: 0.0010
# Epoch 11/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9418 - loss: 0.3052 - val_accuracy: 0.7889 - val_loss: 0.5759 - learning_rate: 0.0010
# Epoch 12/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9324 - loss: 0.3518 - val_accuracy: 0.7916 - val_loss: 0.6347 - learning_rate: 0.0010
# Epoch 13/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9471 - loss: 0.2357 - val_accuracy: 0.7624 - val_loss: 0.7244 - learning_rate: 0.0010
# Epoch 14/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9571 - loss: 0.1752 - val_accuracy: 0.7761 - val_loss: 0.6998 - learning_rate: 0.0010
# Epoch 15/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9588 - loss: 0.2167 - val_accuracy: 0.7854 - val_loss: 0.6298 - learning_rate: 0.0010
# Epoch 16/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9604 - loss: 0.2132 - val_accuracy: 0.8007 - val_loss: 0.7147 - learning_rate: 0.0010
# Epoch 17/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9531 - loss: 0.2572 - val_accuracy: 0.7909 - val_loss: 0.6486 - learning_rate: 0.0010
# Epoch 18/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9595 - loss: 0.1819 - val_accuracy: 0.7949 - val_loss: 0.6722 - learning_rate: 0.0010
# Epoch 19/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9638 - loss: 0.1865 - val_accuracy: 0.7949 - val_loss: 0.5902 - learning_rate: 0.0010
# Epoch 20/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9660 - loss: 0.1840 - val_accuracy: 0.7900 - val_loss: 0.7046 - learning_rate: 0.0010
# Epoch 21/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9659 - loss: 0.1764 - val_accuracy: 0.7921 - val_loss: 0.5800 - learning_rate: 0.0010
# Epoch 22/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9642 - loss: 0.1807 - val_accuracy: 0.8007 - val_loss: 0.5669 - learning_rate: 0.0010
# Epoch 23/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9628 - loss: 0.4480 - val_accuracy: 0.7870 - val_loss: 0.8116 - learning_rate: 0.0010
# Epoch 24/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9663 - loss: 0.2021 - val_accuracy: 0.7944 - val_loss: 0.6717 - learning_rate: 0.0010
# Epoch 25/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9665 - loss: 0.3055 - val_accuracy: 0.7921 - val_loss: 0.6432 - learning_rate: 0.0010
# Epoch 26/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9617 - loss: 0.2348 - val_accuracy: 0.7981 - val_loss: 0.5566 - learning_rate: 0.0010
# Epoch 27/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9738 - loss: 0.1762 - val_accuracy: 0.7728 - val_loss: 0.7300 - learning_rate: 0.0010
# Epoch 28/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9711 - loss: 0.1728 - val_accuracy: 0.8053 - val_loss: 0.5492 - learning_rate: 0.0010
# Epoch 29/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9778 - loss: 0.1550 - val_accuracy: 0.8056 - val_loss: 0.6420 - learning_rate: 0.0010
# Epoch 30/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9800 - loss: 0.3364 - val_accuracy: 0.7984 - val_loss: 0.7990 - learning_rate: 0.0010
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step
# Relatório de Classificação (Validação):
#                precision    recall  f1-score   support
#
#     Classe 0       0.84      0.72      0.78      2101
#     Classe 1       0.77      0.87      0.82      2204
#
#     accuracy                           0.80      4305
#    macro avg       0.80      0.80      0.80      4305
# weighted avg       0.80      0.80      0.80      4305
#
# F1: 0.7966, Recall: 0.7966, Precision: 0.8044, AUC-ROC: 0.8763
# Epoch 1/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 61s 121ms/step - accuracy: 0.6648 - loss: 10.1477 - val_accuracy: 0.7640 - val_loss: 2.5571 - learning_rate: 0.0010
# Epoch 2/30
#   5/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7490 - loss: 2.4888
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py:96: UserWarning: Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.7788 - loss: 1.8954 - val_accuracy: 0.7482 - val_loss: 0.9680 - learning_rate: 0.0010
# Epoch 3/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.8359 - loss: 0.6929 - val_accuracy: 0.7847 - val_loss: 0.5918 - learning_rate: 0.0010
# Epoch 4/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.8572 - loss: 0.4411 - val_accuracy: 0.7905 - val_loss: 0.5654 - learning_rate: 0.0010
# Epoch 5/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.8737 - loss: 0.3811 - val_accuracy: 0.7710 - val_loss: 0.5778 - learning_rate: 0.0010
# Epoch 6/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.8969 - loss: 0.3259 - val_accuracy: 0.8056 - val_loss: 0.4953 - learning_rate: 0.0010
# Epoch 7/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9168 - loss: 0.2803 - val_accuracy: 0.7870 - val_loss: 0.5286 - learning_rate: 0.0010
# Epoch 8/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9197 - loss: 0.4079 - val_accuracy: 0.7868 - val_loss: 0.6135 - learning_rate: 0.0010
# Epoch 9/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.8811 - loss: 0.7146 - val_accuracy: 0.7935 - val_loss: 0.6154 - learning_rate: 0.0010
# Epoch 10/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9178 - loss: 0.3315 - val_accuracy: 0.8156 - val_loss: 0.5316 - learning_rate: 0.0010
# Epoch 11/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9331 - loss: 0.2645 - val_accuracy: 0.8111 - val_loss: 0.5231 - learning_rate: 0.0010
# Epoch 12/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9390 - loss: 0.3313 - val_accuracy: 0.7965 - val_loss: 0.5443 - learning_rate: 0.0010
# Epoch 13/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9510 - loss: 0.2272 - val_accuracy: 0.8105 - val_loss: 0.5173 - learning_rate: 0.0010
# Epoch 14/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9441 - loss: 0.2740 - val_accuracy: 0.7861 - val_loss: 0.6292 - learning_rate: 0.0010
# Epoch 15/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9559 - loss: 0.2114 - val_accuracy: 0.7535 - val_loss: 0.6087 - learning_rate: 0.0010
# Epoch 16/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9534 - loss: 0.2076 - val_accuracy: 0.7912 - val_loss: 0.5683 - learning_rate: 0.0010
# Epoch 17/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9572 - loss: 0.2169 - val_accuracy: 0.7898 - val_loss: 0.7057 - learning_rate: 0.0010
# Epoch 18/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9602 - loss: 0.2003 - val_accuracy: 0.8053 - val_loss: 0.5805 - learning_rate: 0.0010
# Epoch 19/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9548 - loss: 0.3145 - val_accuracy: 0.7610 - val_loss: 0.6415 - learning_rate: 0.0010
# Epoch 20/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9459 - loss: 0.3683 - val_accuracy: 0.6413 - val_loss: 0.6875 - learning_rate: 0.0010
# Epoch 21/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9418 - loss: 0.8178 - val_accuracy: 0.8060 - val_loss: 0.6463 - learning_rate: 0.0010
# Epoch 22/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9571 - loss: 0.2829 - val_accuracy: 0.7954 - val_loss: 0.6069 - learning_rate: 0.0010
# Epoch 23/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9550 - loss: 0.2141 - val_accuracy: 0.8077 - val_loss: 0.5621 - learning_rate: 0.0010
# Epoch 24/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9600 - loss: 0.2732 - val_accuracy: 0.8049 - val_loss: 0.5504 - learning_rate: 0.0010
# Epoch 25/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9667 - loss: 0.1684 - val_accuracy: 0.8070 - val_loss: 0.5447 - learning_rate: 0.0010
# Epoch 26/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9650 - loss: 0.1944 - val_accuracy: 0.7895 - val_loss: 0.5934 - learning_rate: 0.0010
# Epoch 27/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.9688 - loss: 0.1683 - val_accuracy: 0.7958 - val_loss: 0.6132 - learning_rate: 0.0010
# Epoch 28/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.9661 - loss: 0.1807 - val_accuracy: 0.8202 - val_loss: 0.6391 - learning_rate: 0.0010
# Epoch 29/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.9561 - loss: 0.5668 - val_accuracy: 0.8063 - val_loss: 0.6611 - learning_rate: 0.0010
# Epoch 30/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.9678 - loss: 0.1744 - val_accuracy: 0.8088 - val_loss: 0.5925 - learning_rate: 0.0010
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step
# Relatório de Classificação (Validação):
#                precision    recall  f1-score   support
#
#     Classe 0       0.79      0.82      0.81      2101
#     Classe 1       0.82      0.80      0.81      2204
#
#     accuracy                           0.81      4305
#    macro avg       0.81      0.81      0.81      4305
# weighted avg       0.81      0.81      0.81      4305
#
# F1: 0.8088, Recall: 0.8091, Precision: 0.8089, AUC-ROC: 0.8878
# [[(0.7881772669888121, 0.7882692311013104, 0.7961592980327247, 0.8658567331087322), (0.7966269841269842, 0.7966124937481158, 0.804375623268698, 0.8762828780003645), (0.8088135758946183, 0.8090900236772568, 0.8089291079504151, 0.8878149589124874)]]

# %%
model = melhor_model

# %%
Y_test = np.array(Y_test)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Certifique-se de que X_test e Y_test tenham a forma correta
print(f"Forma de X_test: {X_test.shape}")
print(f"Forma de Y_test: {Y_test.shape}")

# Verifique se X_test não está vazio
if X_test.size == 0:
    raise ValueError("X_test está vazio")

# Realize a predição
previsoes = model.predict(X_test)

# Verifique a forma das previsões
print(f"Forma das previsões: {previsoes.shape}")

# Converta as previsões para binário
previsoes_binarias = [1 if x > 0.5 else 0 for x in previsoes]

# Avaliação da acurácia
acuracia = accuracy_score(Y_test, previsoes_binarias)
print(f"Acurácia no conjunto de teste: {acuracia}")

# Matriz de Confusão
matriz_confusao = confusion_matrix(Y_test, previsoes_binarias)
print("Matriz de Confusão:\n", matriz_confusao)

# Plot da Matriz de Confusão
plt.figure(figsize=(10, 7))
sns.heatmap(matriz_confusao, annot=True, fmt="d", cmap="Blues", xticklabels=["Classe Negativa", "Classe Positiva"], yticklabels=["Classe Negativa", "Classe Positiva"])
plt.title('Matriz de Confusão')
plt.ylabel('Valor Real')
plt.xlabel('Valor Previsto')
plt.show()

# Relatório de Classificação
relatorio_classificacao = classification_report(Y_test, previsoes_binarias, target_names=["Classe 0", "Classe 1"])
print("Relatório de Classificação:\n", relatorio_classificacao)
# Out:
# Forma de X_test: (1990, 100, 100, 3)
# Forma de Y_test: (1990,)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step
# Forma das previsões: (1990, 1)
# Acurácia no conjunto de teste: 0.800502512562814
# Matriz de Confusão:
#  [[1322  240]
#  [ 157  271]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#     Classe 0       0.89      0.85      0.87      1562
#     Classe 1       0.53      0.63      0.58       428
#
#     accuracy                           0.80      1990
#    macro avg       0.71      0.74      0.72      1990
# weighted avg       0.82      0.80      0.81      1990

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

def train_model(model, X_train, Y_train, EPOCHS=30):
    # Usando 'val_accuracy' em vez de 'val_acc'
    early_stop = EarlyStopping(monitor='val_accuracy', patience=10,verbose=1,
                               mode='max', restore_best_weights=True)

    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=5,
                                  verbose=1, mode='max', min_lr=1e-5)

    history = model.fit(X_train,
                        Y_train,
                        validation_split=0.2,
                        batch_size=16,
                        epochs=EPOCHS,
                        callbacks=[reduce_lr, early_stop])
    return history

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np  # Importe a biblioteca NumPy

# Listas para armazenar as métricas de cada iteração
accuracies = []
precisions = []
recalls = []
f1_scores = []
historys = []
if(bf==0):
    treinox = x_train_1
    treinoy = y_train_1
    print("melor fold = 1")
elif(bf==1):
    treinox = x_train_2
    treinoy = y_train_2
    print("melor fold = 2")
else:
    treinox = x_train_3
    treinoy = y_train_3
    print("melor fold = 3")

for i in range(10):
    print("OIBOMDIA",i)
    tf.keras.backend.clear_session()
    model = create_inceptionV3_L()
    historys.append(train_model(model, treinox, treinoy, 30))

    previsoes = model.predict(X_test)
    previsoes_binarias = [1 if x > 0.5 else 0 for x in previsoes]

    # Adiciona a acurácia à lista
    acuracia = accuracy_score(Y_test, previsoes_binarias)
    accuracies.append(acuracia)

    # Calcula e adiciona precisão, recall e f1-score à suas respectivas listas
    relatorio_classificacao = classification_report(Y_test, previsoes_binarias, target_names=["Classe 0", "Classe 1"], output_dict=True)
    # Capturando os valores individuais de precisão, recall e F1-score para a classe '1'
    precisao_classe_1 = relatorio_classificacao['macro avg']['precision']
    recall_classe_1 = relatorio_classificacao['macro avg']['recall']
    f1_score_classe_1 = relatorio_classificacao['macro avg']['f1-score']

    print(f"Precisão : {precisao_classe_1}")
    print(f"Recall : {recall_classe_1}")
    print(f"F1-Score : {f1_score_classe_1}")

    precisions.append(precisao_classe_1)
    recalls.append(recall_classe_1)
    f1_scores.append(f1_score_classe_1)


# Calcula a média de cada métrica
acuracia_media = np.mean(accuracies)
precisao_media = np.mean(precisions)
recall_medio = np.mean(recalls)
f1_score_medio = np.mean(f1_scores)

# Calcula o desvio padrão de cada métrica
acuracia_dp = np.std(accuracies)
precisao_dp = np.std(precisions)
recall_dp = np.std(recalls)
f1_score_dp = np.std(f1_scores)

# Exibe os resultados
print(f"Acurácia média: {acuracia_media} ± {acuracia_dp}")
print(f"Precisão média: {precisao_media} ± {precisao_dp}")
print(f"Recall médio: {recall_medio} ± {recall_dp}")
print(f"F1-Score médio: {f1_score_medio} ± {f1_score_dp}")

# Opção para plotar a matriz de confusão da última iteração
cm = confusion_matrix(Y_test, previsoes_binarias)
sns.heatmap(cm, annot=True, fmt="d")
plt.xlabel('Predito')
plt.ylabel('Verdadeiro')
plt.show()

import matplotlib.pyplot as plt

# Configuração do gráfico de Acurácia
plt.figure(figsize=(14, 5))

# Gráfico de Acurácia por Época para cada history
plt.subplot(1, 2, 1)  # 1 linha, 2 colunas, posição 1
for history in historys:
    plt.plot(history.history['accuracy'], label='Acurácia (treino)')
    plt.plot(history.history['val_accuracy'], label='Acurácia (validação)')
plt.title('Acurácia por Época')
plt.xlabel('Época')
plt.ylabel('Acurácia')
plt.legend()

# Configuração do gráfico de Loss
plt.subplot(1, 2, 2)  # 1 linha, 2 colunas, posição 2
for history in historys:
    plt.plot(history.history['loss'], label='Loss (treino)')
    plt.plot(history.history['val_loss'], label='Loss (validação)')
plt.title('Loss por Época')
plt.xlabel('Época')
plt.ylabel('Loss')
plt.legend()

plt.show()

plt.ylabel('Acurácia')
plt.xlabel('Época')
plt.legend(['Treino', 'Validação'], loc='upper left')
plt.show()

# Sumarize o histórico de perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Perda do Modelo')
plt.ylabel('Perda')
plt.xlabel('Época')
plt.legend(['Treino', 'Validação'], loc='upper left')
plt.show()
# Out:
# melor fold = 3
# OIBOMDIA 0
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 80s 104ms/step - accuracy: 0.6335 - loss: 9.5859 - val_accuracy: 0.7290 - val_loss: 2.1140 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.7500 - loss: 1.5411 - val_accuracy: 0.7458 - val_loss: 0.7758 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7894 - loss: 0.6615 - val_accuracy: 0.7510 - val_loss: 0.6069 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8192 - loss: 0.5088 - val_accuracy: 0.7208 - val_loss: 0.7249 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8364 - loss: 0.4685 - val_accuracy: 0.7133 - val_loss: 0.6789 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8684 - loss: 0.4082 - val_accuracy: 0.7145 - val_loss: 0.6640 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8778 - loss: 0.3835 - val_accuracy: 0.7464 - val_loss: 0.6393 - learning_rate: 0.0010
# Epoch 8/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8863 - loss: 0.3780
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8862 - loss: 0.3780 - val_accuracy: 0.7487 - val_loss: 0.6710 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9283 - loss: 0.2888 - val_accuracy: 0.7539 - val_loss: 0.6400 - learning_rate: 1.0000e-04
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9382 - loss: 0.2027 - val_accuracy: 0.7528 - val_loss: 0.6602 - learning_rate: 1.0000e-04
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9442 - loss: 0.1767 - val_accuracy: 0.7603 - val_loss: 0.6271 - learning_rate: 1.0000e-04
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9559 - loss: 0.1476 - val_accuracy: 0.7481 - val_loss: 0.7916 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9627 - loss: 0.1301 - val_accuracy: 0.7615 - val_loss: 0.7437 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9635 - loss: 0.1291 - val_accuracy: 0.7603 - val_loss: 0.7187 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9682 - loss: 0.1231 - val_accuracy: 0.7603 - val_loss: 0.7315 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9628 - loss: 0.1315 - val_accuracy: 0.7626 - val_loss: 0.7633 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9695 - loss: 0.1137 - val_accuracy: 0.7638 - val_loss: 0.7538 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9682 - loss: 0.1169 - val_accuracy: 0.7557 - val_loss: 0.7697 - learning_rate: 1.0000e-04
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9746 - loss: 0.1065 - val_accuracy: 0.7644 - val_loss: 0.8592 - learning_rate: 1.0000e-04
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9786 - loss: 0.0970 - val_accuracy: 0.7667 - val_loss: 0.7349 - learning_rate: 1.0000e-04
# Epoch 21/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9805 - loss: 0.0951 - val_accuracy: 0.7522 - val_loss: 0.7557 - learning_rate: 1.0000e-04
# Epoch 22/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9835 - loss: 0.0904 - val_accuracy: 0.7609 - val_loss: 0.8918 - learning_rate: 1.0000e-04
# Epoch 23/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9825 - loss: 0.0820 - val_accuracy: 0.7678 - val_loss: 0.9529 - learning_rate: 1.0000e-04
# Epoch 24/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9807 - loss: 0.0922 - val_accuracy: 0.7632 - val_loss: 0.8290 - learning_rate: 1.0000e-04
# Epoch 25/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9816 - loss: 0.0965 - val_accuracy: 0.7638 - val_loss: 0.9204 - learning_rate: 1.0000e-04
# Epoch 26/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9832 - loss: 0.0870 - val_accuracy: 0.7574 - val_loss: 0.9279 - learning_rate: 1.0000e-04
# Epoch 27/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9876 - loss: 0.0703 - val_accuracy: 0.7551 - val_loss: 0.9186 - learning_rate: 1.0000e-04
# Epoch 28/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9883 - loss: 0.0629
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9883 - loss: 0.0630 - val_accuracy: 0.7620 - val_loss: 0.8510 - learning_rate: 1.0000e-04
# Epoch 29/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9853 - loss: 0.0820 - val_accuracy: 0.7626 - val_loss: 0.8699 - learning_rate: 1.0000e-05
# Epoch 30/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9913 - loss: 0.0583 - val_accuracy: 0.7632 - val_loss: 0.9060 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 23.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 98ms/step
# Precisão : 0.6922984086188199
# Recall : 0.7538262711357354
# F1-Score : 0.7058221156509422
# OIBOMDIA 1
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 63s 79ms/step - accuracy: 0.6438 - loss: 9.5027 - val_accuracy: 0.7330 - val_loss: 2.1116 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.7615 - loss: 1.4953 - val_accuracy: 0.7545 - val_loss: 0.8752 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7979 - loss: 0.6775 - val_accuracy: 0.7092 - val_loss: 0.6928 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8217 - loss: 0.5011 - val_accuracy: 0.7493 - val_loss: 0.6766 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8510 - loss: 0.4511 - val_accuracy: 0.7528 - val_loss: 0.6329 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8494 - loss: 0.4201 - val_accuracy: 0.7441 - val_loss: 0.6462 - learning_rate: 0.0010
# Epoch 7/30
# 429/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8578 - loss: 0.4043
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8578 - loss: 0.4044 - val_accuracy: 0.7435 - val_loss: 0.6075 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9041 - loss: 0.2991 - val_accuracy: 0.7481 - val_loss: 0.6033 - learning_rate: 1.0000e-04
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9360 - loss: 0.2051 - val_accuracy: 0.7423 - val_loss: 0.6527 - learning_rate: 1.0000e-04
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9416 - loss: 0.1763 - val_accuracy: 0.7406 - val_loss: 0.6949 - learning_rate: 1.0000e-04
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9473 - loss: 0.1768 - val_accuracy: 0.7481 - val_loss: 0.7305 - learning_rate: 1.0000e-04
# Epoch 12/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9533 - loss: 0.1492
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9533 - loss: 0.1492 - val_accuracy: 0.7446 - val_loss: 0.7684 - learning_rate: 1.0000e-04
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 100ms/step
# Precisão : 0.6871476551393477
# Recall : 0.7341280050737732
# F1-Score : 0.7008866212189833
# OIBOMDIA 2
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 63s 78ms/step - accuracy: 0.6326 - loss: 9.6298 - val_accuracy: 0.7232 - val_loss: 2.3700 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7449 - loss: 1.6078 - val_accuracy: 0.7156 - val_loss: 0.8418 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7849 - loss: 0.6836 - val_accuracy: 0.7499 - val_loss: 0.6902 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8271 - loss: 0.5007 - val_accuracy: 0.7249 - val_loss: 0.6457 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8369 - loss: 0.4541 - val_accuracy: 0.7255 - val_loss: 0.8581 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8505 - loss: 0.4507 - val_accuracy: 0.7365 - val_loss: 0.6528 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8722 - loss: 0.3956 - val_accuracy: 0.6837 - val_loss: 0.7003 - learning_rate: 0.0010
# Epoch 8/30
# 429/431 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8797 - loss: 0.3769
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8796 - loss: 0.3770 - val_accuracy: 0.7197 - val_loss: 0.7490 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9056 - loss: 0.3286 - val_accuracy: 0.7388 - val_loss: 0.6405 - learning_rate: 1.0000e-04
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9188 - loss: 0.2297 - val_accuracy: 0.7499 - val_loss: 0.6302 - learning_rate: 1.0000e-04
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9232 - loss: 0.2238 - val_accuracy: 0.7475 - val_loss: 0.6436 - learning_rate: 1.0000e-04
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9427 - loss: 0.1818 - val_accuracy: 0.7522 - val_loss: 0.7449 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9475 - loss: 0.1660 - val_accuracy: 0.7533 - val_loss: 0.6717 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9564 - loss: 0.1581 - val_accuracy: 0.7591 - val_loss: 0.7173 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9488 - loss: 0.1820 - val_accuracy: 0.7423 - val_loss: 0.6711 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9605 - loss: 0.1385 - val_accuracy: 0.7475 - val_loss: 0.7812 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9644 - loss: 0.1380 - val_accuracy: 0.7510 - val_loss: 0.7348 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9576 - loss: 0.1468 - val_accuracy: 0.7516 - val_loss: 0.6974 - learning_rate: 1.0000e-04
# Epoch 19/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9642 - loss: 0.1353
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9642 - loss: 0.1353 - val_accuracy: 0.7406 - val_loss: 0.9180 - learning_rate: 1.0000e-04
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9775 - loss: 0.0992 - val_accuracy: 0.7452 - val_loss: 0.7871 - learning_rate: 1.0000e-05
# Epoch 21/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9767 - loss: 0.1022 - val_accuracy: 0.7429 - val_loss: 0.7976 - learning_rate: 1.0000e-05
# Epoch 22/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9788 - loss: 0.0933 - val_accuracy: 0.7458 - val_loss: 0.8245 - learning_rate: 1.0000e-05
# Epoch 23/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9832 - loss: 0.0826 - val_accuracy: 0.7464 - val_loss: 0.8261 - learning_rate: 1.0000e-05
# Epoch 24/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9834 - loss: 0.0815
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9834 - loss: 0.0815 - val_accuracy: 0.7458 - val_loss: 0.8719 - learning_rate: 1.0000e-05
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 100ms/step
# Precisão : 0.7054340637937438
# Recall : 0.7713660894850838
# F1-Score : 0.7204688338378367
# OIBOMDIA 3
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 63s 79ms/step - accuracy: 0.6404 - loss: 9.7919 - val_accuracy: 0.7185 - val_loss: 2.4959 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.7481 - loss: 1.6590 - val_accuracy: 0.7377 - val_loss: 0.8695 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7835 - loss: 0.6910 - val_accuracy: 0.7475 - val_loss: 0.8290 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8158 - loss: 0.5056 - val_accuracy: 0.7423 - val_loss: 0.6098 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.8409 - loss: 0.4360 - val_accuracy: 0.7504 - val_loss: 0.6361 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8519 - loss: 0.4228 - val_accuracy: 0.7406 - val_loss: 0.7066 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8631 - loss: 0.3924 - val_accuracy: 0.6477 - val_loss: 2.5680 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8809 - loss: 0.3829 - val_accuracy: 0.7499 - val_loss: 0.6586 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8900 - loss: 0.3664 - val_accuracy: 0.7452 - val_loss: 0.6112 - learning_rate: 0.0010
# Epoch 10/30
# 429/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8985 - loss: 0.3716
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8985 - loss: 0.3716 - val_accuracy: 0.7435 - val_loss: 0.6537 - learning_rate: 0.0010
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.9217 - loss: 0.2697 - val_accuracy: 0.7562 - val_loss: 0.6279 - learning_rate: 1.0000e-04
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9359 - loss: 0.2101 - val_accuracy: 0.7562 - val_loss: 0.6251 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9433 - loss: 0.1830 - val_accuracy: 0.7562 - val_loss: 0.6150 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9573 - loss: 0.1508 - val_accuracy: 0.7539 - val_loss: 0.7852 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9595 - loss: 0.1451 - val_accuracy: 0.7545 - val_loss: 0.6787 - learning_rate: 1.0000e-04
# Epoch 16/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9621 - loss: 0.1526
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9621 - loss: 0.1527 - val_accuracy: 0.7232 - val_loss: 0.9693 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9705 - loss: 0.1219 - val_accuracy: 0.7441 - val_loss: 0.8164 - learning_rate: 1.0000e-05
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9769 - loss: 0.1029 - val_accuracy: 0.7429 - val_loss: 0.8156 - learning_rate: 1.0000e-05
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9797 - loss: 0.0996 - val_accuracy: 0.7429 - val_loss: 0.7915 - learning_rate: 1.0000e-05
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.9803 - loss: 0.0889 - val_accuracy: 0.7429 - val_loss: 0.8522 - learning_rate: 1.0000e-05
# Epoch 21/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9853 - loss: 0.0858
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9853 - loss: 0.0858 - val_accuracy: 0.7441 - val_loss: 0.9024 - learning_rate: 1.0000e-05
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 101ms/step
# Precisão : 0.7016915831043917
# Recall : 0.762564768389436
# F1-Score : 0.7167627635868635
# OIBOMDIA 4
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 63s 79ms/step - accuracy: 0.6313 - loss: 9.5303 - val_accuracy: 0.6843 - val_loss: 2.0180 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7445 - loss: 1.4285 - val_accuracy: 0.7145 - val_loss: 0.9873 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7847 - loss: 0.6266 - val_accuracy: 0.7435 - val_loss: 0.6829 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8157 - loss: 0.4905 - val_accuracy: 0.7168 - val_loss: 0.7936 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8521 - loss: 0.4376 - val_accuracy: 0.7353 - val_loss: 0.6048 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8498 - loss: 0.4277 - val_accuracy: 0.7557 - val_loss: 0.5995 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8701 - loss: 0.3859 - val_accuracy: 0.7133 - val_loss: 1.1720 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8778 - loss: 0.3943 - val_accuracy: 0.7052 - val_loss: 0.7095 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9016 - loss: 0.3461 - val_accuracy: 0.7226 - val_loss: 0.6321 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8908 - loss: 0.3532 - val_accuracy: 0.7487 - val_loss: 0.5943 - learning_rate: 0.0010
# Epoch 11/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8921 - loss: 0.3513
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8921 - loss: 0.3513 - val_accuracy: 0.7348 - val_loss: 0.8245 - learning_rate: 0.0010
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9218 - loss: 0.2898 - val_accuracy: 0.7470 - val_loss: 0.6625 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9406 - loss: 0.2095 - val_accuracy: 0.7464 - val_loss: 0.6676 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9461 - loss: 0.1835 - val_accuracy: 0.7377 - val_loss: 0.7593 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9522 - loss: 0.1582 - val_accuracy: 0.7510 - val_loss: 0.7340 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9645 - loss: 0.1352
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9645 - loss: 0.1352 - val_accuracy: 0.7487 - val_loss: 0.7005 - learning_rate: 1.0000e-04
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 99ms/step
# Precisão : 0.6921787444764308
# Recall : 0.7669145715413979
# F1-Score : 0.7011264080100125
# OIBOMDIA 5
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 62s 78ms/step - accuracy: 0.6378 - loss: 9.6608 - val_accuracy: 0.6558 - val_loss: 2.4891 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7390 - loss: 1.5411 - val_accuracy: 0.6965 - val_loss: 0.9157 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7886 - loss: 0.6569 - val_accuracy: 0.7441 - val_loss: 0.6114 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8264 - loss: 0.4886 - val_accuracy: 0.7423 - val_loss: 0.6688 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.8367 - loss: 0.4372 - val_accuracy: 0.7255 - val_loss: 0.6344 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8557 - loss: 0.4073 - val_accuracy: 0.7075 - val_loss: 0.7979 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8736 - loss: 0.3800 - val_accuracy: 0.7255 - val_loss: 0.6411 - learning_rate: 0.0010
# Epoch 8/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8731 - loss: 0.3675
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8730 - loss: 0.3676 - val_accuracy: 0.7365 - val_loss: 0.7189 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8991 - loss: 0.3135 - val_accuracy: 0.7441 - val_loss: 0.5925 - learning_rate: 1.0000e-04
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9154 - loss: 0.2516 - val_accuracy: 0.7400 - val_loss: 0.6773 - learning_rate: 1.0000e-04
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9168 - loss: 0.2199 - val_accuracy: 0.7539 - val_loss: 0.6070 - learning_rate: 1.0000e-04
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9228 - loss: 0.2080 - val_accuracy: 0.7475 - val_loss: 0.6239 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9299 - loss: 0.1831 - val_accuracy: 0.7452 - val_loss: 0.7291 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9392 - loss: 0.1705 - val_accuracy: 0.7441 - val_loss: 0.6756 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9437 - loss: 0.1677 - val_accuracy: 0.7452 - val_loss: 0.7378 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9510 - loss: 0.1424
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9510 - loss: 0.1424 - val_accuracy: 0.7417 - val_loss: 0.7087 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9568 - loss: 0.1371 - val_accuracy: 0.7533 - val_loss: 0.7083 - learning_rate: 1.0000e-05
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9646 - loss: 0.1183 - val_accuracy: 0.7522 - val_loss: 0.7141 - learning_rate: 1.0000e-05
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9715 - loss: 0.1105 - val_accuracy: 0.7464 - val_loss: 0.8121 - learning_rate: 1.0000e-05
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9757 - loss: 0.1029 - val_accuracy: 0.7470 - val_loss: 0.7766 - learning_rate: 1.0000e-05
# Epoch 21/30
# 429/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9837 - loss: 0.0794
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9837 - loss: 0.0794 - val_accuracy: 0.7470 - val_loss: 0.8587 - learning_rate: 1.0000e-05
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 98ms/step
# Precisão : 0.7082754578754579
# Recall : 0.765782246580588
# F1-Score : 0.7243043855047043
# OIBOMDIA 6
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.6581 - loss: 9.5072 - val_accuracy: 0.7028 - val_loss: 2.1779 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7410 - loss: 1.5701 - val_accuracy: 0.7336 - val_loss: 0.8163 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7861 - loss: 0.6972 - val_accuracy: 0.7110 - val_loss: 0.7208 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7988 - loss: 0.5387 - val_accuracy: 0.7237 - val_loss: 0.6249 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8250 - loss: 0.4513 - val_accuracy: 0.6918 - val_loss: 0.7455 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8487 - loss: 0.4275 - val_accuracy: 0.7249 - val_loss: 0.6209 - learning_rate: 0.0010
# Epoch 7/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8567 - loss: 0.4023
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8567 - loss: 0.4024 - val_accuracy: 0.7208 - val_loss: 0.6666 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8804 - loss: 0.3409 - val_accuracy: 0.7441 - val_loss: 0.5968 - learning_rate: 1.0000e-04
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9052 - loss: 0.2548 - val_accuracy: 0.7539 - val_loss: 0.6312 - learning_rate: 1.0000e-04
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9151 - loss: 0.2277 - val_accuracy: 0.7522 - val_loss: 0.6881 - learning_rate: 1.0000e-04
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9397 - loss: 0.1877 - val_accuracy: 0.7551 - val_loss: 0.6901 - learning_rate: 1.0000e-04
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9418 - loss: 0.1812 - val_accuracy: 0.7353 - val_loss: 0.7876 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9488 - loss: 0.1652 - val_accuracy: 0.7609 - val_loss: 0.7148 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9582 - loss: 0.1549 - val_accuracy: 0.7452 - val_loss: 0.7516 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9577 - loss: 0.1393 - val_accuracy: 0.7516 - val_loss: 0.7527 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9655 - loss: 0.1344 - val_accuracy: 0.7353 - val_loss: 0.8657 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9677 - loss: 0.1264 - val_accuracy: 0.7557 - val_loss: 0.8177 - learning_rate: 1.0000e-04
# Epoch 18/30
# 429/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9692 - loss: 0.1282
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9692 - loss: 0.1282 - val_accuracy: 0.7452 - val_loss: 0.8805 - learning_rate: 1.0000e-04
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9801 - loss: 0.1014 - val_accuracy: 0.7591 - val_loss: 0.8328 - learning_rate: 1.0000e-05
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9864 - loss: 0.0860 - val_accuracy: 0.7603 - val_loss: 0.8405 - learning_rate: 1.0000e-05
# Epoch 21/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9838 - loss: 0.0883 - val_accuracy: 0.7545 - val_loss: 0.9061 - learning_rate: 1.0000e-05
# Epoch 22/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9837 - loss: 0.0864 - val_accuracy: 0.7481 - val_loss: 0.9108 - learning_rate: 1.0000e-05
# Epoch 23/30
# 429/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9872 - loss: 0.0769
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9872 - loss: 0.0769 - val_accuracy: 0.7499 - val_loss: 0.9170 - learning_rate: 1.0000e-05
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 99ms/step
# Precisão : 0.720063592077244
# Recall : 0.7708246077997296
# F1-Score : 0.7366538055889164
# OIBOMDIA 7
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 62s 77ms/step - accuracy: 0.6491 - loss: 9.8254 - val_accuracy: 0.7191 - val_loss: 2.2686 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7471 - loss: 1.6754 - val_accuracy: 0.7208 - val_loss: 0.9120 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7983 - loss: 0.6629 - val_accuracy: 0.7191 - val_loss: 0.6836 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8233 - loss: 0.5122 - val_accuracy: 0.7551 - val_loss: 0.5897 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8556 - loss: 0.4267 - val_accuracy: 0.6970 - val_loss: 0.6961 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8629 - loss: 0.4059 - val_accuracy: 0.7324 - val_loss: 0.6117 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8751 - loss: 0.3997 - val_accuracy: 0.7411 - val_loss: 0.6409 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8800 - loss: 0.3847 - val_accuracy: 0.7075 - val_loss: 0.8107 - learning_rate: 0.0010
# Epoch 9/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8993 - loss: 0.3426
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8993 - loss: 0.3427 - val_accuracy: 0.7394 - val_loss: 0.6910 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9085 - loss: 0.2958 - val_accuracy: 0.7516 - val_loss: 0.6106 - learning_rate: 1.0000e-04
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.9289 - loss: 0.2258 - val_accuracy: 0.7562 - val_loss: 0.6116 - learning_rate: 1.0000e-04
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9399 - loss: 0.1940 - val_accuracy: 0.7528 - val_loss: 0.6279 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9522 - loss: 0.1581 - val_accuracy: 0.7562 - val_loss: 0.5907 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9507 - loss: 0.1639 - val_accuracy: 0.7574 - val_loss: 0.6939 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9555 - loss: 0.1521 - val_accuracy: 0.7510 - val_loss: 0.6756 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9607 - loss: 0.1460 - val_accuracy: 0.7388 - val_loss: 0.6673 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9726 - loss: 0.1167 - val_accuracy: 0.7371 - val_loss: 0.7016 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9728 - loss: 0.1186 - val_accuracy: 0.7574 - val_loss: 0.7726 - learning_rate: 1.0000e-04
# Epoch 19/30
# 429/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9724 - loss: 0.1231
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9723 - loss: 0.1231 - val_accuracy: 0.7435 - val_loss: 0.9744 - learning_rate: 1.0000e-04
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9815 - loss: 0.0940 - val_accuracy: 0.7574 - val_loss: 0.8328 - learning_rate: 1.0000e-05
# Epoch 21/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9806 - loss: 0.0996 - val_accuracy: 0.7510 - val_loss: 0.8168 - learning_rate: 1.0000e-05
# Epoch 22/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9760 - loss: 0.1005 - val_accuracy: 0.7533 - val_loss: 0.8509 - learning_rate: 1.0000e-05
# Epoch 23/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.9818 - loss: 0.0903 - val_accuracy: 0.7452 - val_loss: 0.8906 - learning_rate: 1.0000e-05
# Epoch 24/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9847 - loss: 0.0736
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.9847 - loss: 0.0736 - val_accuracy: 0.7493 - val_loss: 0.8762 - learning_rate: 1.0000e-05
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 100ms/step
# Precisão : 0.7089517435300113
# Recall : 0.7747750308135987
# F1-Score : 0.7245674740484429
# OIBOMDIA 8
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 64s 81ms/step - accuracy: 0.6468 - loss: 9.6937 - val_accuracy: 0.7174 - val_loss: 2.2107 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.7385 - loss: 1.5899 - val_accuracy: 0.6970 - val_loss: 0.8301 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.7945 - loss: 0.6463 - val_accuracy: 0.7504 - val_loss: 0.6492 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.8071 - loss: 0.5090 - val_accuracy: 0.7174 - val_loss: 0.7672 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.8264 - loss: 0.4769 - val_accuracy: 0.7435 - val_loss: 0.6943 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.8387 - loss: 0.4207 - val_accuracy: 0.7359 - val_loss: 0.6189 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8588 - loss: 0.3957 - val_accuracy: 0.7411 - val_loss: 0.7157 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8524 - loss: 0.4240
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8524 - loss: 0.4240 - val_accuracy: 0.7411 - val_loss: 0.7746 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8972 - loss: 0.3447 - val_accuracy: 0.7702 - val_loss: 0.5928 - learning_rate: 1.0000e-04
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9291 - loss: 0.2415 - val_accuracy: 0.7713 - val_loss: 0.6054 - learning_rate: 1.0000e-04
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9434 - loss: 0.1851 - val_accuracy: 0.7487 - val_loss: 0.6725 - learning_rate: 1.0000e-04
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9545 - loss: 0.1650 - val_accuracy: 0.7388 - val_loss: 0.8031 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9575 - loss: 0.1464 - val_accuracy: 0.7551 - val_loss: 0.6286 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9669 - loss: 0.1267 - val_accuracy: 0.7574 - val_loss: 0.6886 - learning_rate: 1.0000e-04
# Epoch 15/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9618 - loss: 0.1360
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9618 - loss: 0.1360 - val_accuracy: 0.7400 - val_loss: 0.8028 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9688 - loss: 0.1207 - val_accuracy: 0.7539 - val_loss: 0.7838 - learning_rate: 1.0000e-05
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9758 - loss: 0.1013 - val_accuracy: 0.7551 - val_loss: 0.7911 - learning_rate: 1.0000e-05
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9782 - loss: 0.0998 - val_accuracy: 0.7481 - val_loss: 0.8185 - learning_rate: 1.0000e-05
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9822 - loss: 0.0893 - val_accuracy: 0.7499 - val_loss: 0.8350 - learning_rate: 1.0000e-05
# Epoch 20/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9790 - loss: 0.0901
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9790 - loss: 0.0901 - val_accuracy: 0.7510 - val_loss: 0.8320 - learning_rate: 1.0000e-05
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 98ms/step
# Precisão : 0.6999365305513299
# Recall : 0.7695247525937272
# F1-Score : 0.7131364078614517
# OIBOMDIA 9
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 63s 79ms/step - accuracy: 0.6365 - loss: 9.6580 - val_accuracy: 0.7446 - val_loss: 2.1364 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7540 - loss: 1.5939 - val_accuracy: 0.7249 - val_loss: 0.8665 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7956 - loss: 0.6734 - val_accuracy: 0.6837 - val_loss: 0.6846 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8110 - loss: 0.5253 - val_accuracy: 0.7458 - val_loss: 0.6007 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8317 - loss: 0.4471 - val_accuracy: 0.7301 - val_loss: 0.6022 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8460 - loss: 0.4340 - val_accuracy: 0.6558 - val_loss: 0.9388 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8618 - loss: 0.4111 - val_accuracy: 0.7382 - val_loss: 0.6516 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8798 - loss: 0.3908 - val_accuracy: 0.6483 - val_loss: 0.8240 - learning_rate: 0.0010
# Epoch 9/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8855 - loss: 0.3725
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8855 - loss: 0.3725 - val_accuracy: 0.7174 - val_loss: 0.6485 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9257 - loss: 0.2835 - val_accuracy: 0.7458 - val_loss: 0.6481 - learning_rate: 1.0000e-04
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9240 - loss: 0.2285 - val_accuracy: 0.7487 - val_loss: 0.6836 - learning_rate: 1.0000e-04
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9428 - loss: 0.1909 - val_accuracy: 0.7481 - val_loss: 0.7145 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9499 - loss: 0.1712 - val_accuracy: 0.7452 - val_loss: 0.7293 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9541 - loss: 0.1630 - val_accuracy: 0.7574 - val_loss: 0.7633 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9535 - loss: 0.1560 - val_accuracy: 0.7522 - val_loss: 0.7103 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9604 - loss: 0.1411 - val_accuracy: 0.7516 - val_loss: 0.7669 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9656 - loss: 0.1293 - val_accuracy: 0.7568 - val_loss: 0.7721 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9729 - loss: 0.1155 - val_accuracy: 0.7533 - val_loss: 0.7584 - learning_rate: 1.0000e-04
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9730 - loss: 0.1142 - val_accuracy: 0.7597 - val_loss: 0.6934 - learning_rate: 1.0000e-04
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9820 - loss: 0.0877 - val_accuracy: 0.7539 - val_loss: 0.8791 - learning_rate: 1.0000e-04
# Epoch 21/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9767 - loss: 0.0994 - val_accuracy: 0.7493 - val_loss: 0.7256 - learning_rate: 1.0000e-04
# Epoch 22/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9780 - loss: 0.1006 - val_accuracy: 0.7620 - val_loss: 0.8796 - learning_rate: 1.0000e-04
# Epoch 23/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9777 - loss: 0.1002 - val_accuracy: 0.7562 - val_loss: 0.9960 - learning_rate: 1.0000e-04
# Epoch 24/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9873 - loss: 0.0781 - val_accuracy: 0.7574 - val_loss: 1.0742 - learning_rate: 1.0000e-04
# Epoch 25/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9758 - loss: 0.1011 - val_accuracy: 0.7551 - val_loss: 0.9234 - learning_rate: 1.0000e-04
# Epoch 26/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9812 - loss: 0.0894 - val_accuracy: 0.7696 - val_loss: 0.9939 - learning_rate: 1.0000e-04
# Epoch 27/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9808 - loss: 0.0924 - val_accuracy: 0.7185 - val_loss: 1.1337 - learning_rate: 1.0000e-04
# Epoch 28/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9855 - loss: 0.0843 - val_accuracy: 0.7539 - val_loss: 0.9517 - learning_rate: 1.0000e-04
# Epoch 29/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9881 - loss: 0.0732 - val_accuracy: 0.7499 - val_loss: 1.0004 - learning_rate: 1.0000e-04
# Epoch 30/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9852 - loss: 0.0839 - val_accuracy: 0.7359 - val_loss: 0.7813 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 26.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 100ms/step
# Precisão : 0.694022735367962
# Recall : 0.7672511278375436
# F1-Score : 0.704347028613353
# Acurácia média: 0.7729648241206031 ± 0.013563744031152422
# Precisão média: 0.701000051453474 ± 0.009460206937336556
# Recall médio: 0.7636957471250614 ± 0.011254664455554647
# F1-Score médio: 0.7148075843921506 ± 0.01128050104643993
